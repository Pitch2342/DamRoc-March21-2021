# %%
import os
import torch
import random
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from utils.utils import load_parameters, stack_tensors
from datasets.datasets import load_data
from inner_maximizers.inner_maximizers import inner_maximizer
from nets.ff_classifier import build_ff_classifier
import losswise
import time
import json
import numpy as np

# %%
parameters = load_parameters("parameters.ini")
is_cuda = eval(parameters["general"]["is_cuda"])
if is_cuda:
    os.environ["CUDA_VISIBLE_DEVICES"] = parameters["general"]["gpu_device"]

assertion_message = "Set this flag off to train models."
assert eval(parameters['dataset']['generate_feature_vector_files']) is False, assertion_message

log_interval = int(parameters["general"]["log_interval"])
num_epochs = int(parameters["hyperparam"]["ff_num_epochs"])
is_losswise = eval(parameters["general"]["is_losswise"])
is_synthetic_dataset = eval(parameters["general"]["is_synthetic_dataset"])

training_method = parameters["general"]["training_method"]
evasion_method = parameters["general"]["evasion_method"]
experiment_suffix = parameters["general"]["experiment_suffix"]
experiment_name = "[training:%s|evasion:%s]_%s" % (training_method, evasion_method,
                                                   experiment_suffix)

print("Training Method:%s, Evasion Method:%s" % (training_method, evasion_method))

seed_val = int(parameters["general"]["seed"])

random.seed(seed_val)
torch.manual_seed(seed_val)
np.random.seed(seed_val)
# Out:
# Training Method:rfgsm_k, Evasion Method:natural

# %%
evasion_iterations = int(parameters['hyperparam']['evasion_iterations'])

save_every_epoch = eval(parameters['general']['save_every_epoch'])

train_model_from_scratch = eval(parameters['general']['train_model_from_scratch'])
load_model_weights = eval(parameters['general']['load_model_weights'])
model_weights_path = parameters['general']['model_weights_path']

# %%
train_dataloader_dict, valid_dataloader_dict, test_dataloader_dict, num_features = load_data(
    parameters)
# Out:
# Starting data loading
# Creating import to index mapping
# -- accessing file: ./helper_files/N5000/pmal/
# -- accessing file: ./helper_files/N5000/pben/
# Malicious files: 500
# Benign files: 500
# Total number of files: 1000
# 0 Time: 0.0  seconds
# 100 Time: 0.11867260932922363  seconds
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# ...
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'

# %%
num_samples = len(train_dataloader_dict["malicious"].dataset)

# %%
model = build_ff_classifier(
        input_size=num_features,
        hidden_1_size=int(parameters["hyperparam"]["ff_h1"]),
        hidden_2_size=int(parameters["hyperparam"]["ff_h2"]),
        hidden_3_size=int(parameters["hyperparam"]["ff_h3"]))
model
# Out:
# Sequential(
#   (0): Linear(in_features=2948, out_features=300, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=300, out_features=300, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=300, out_features=300, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=300, out_features=2, bias=True)
#   (7): LogSoftmax(dim=1)
# )

# %%
import torch.nn.functional as F

def get_beta(batch_idx, m, beta_type, epoch, num_epochs):
    if beta_type == "Blundell":
        beta = 2 ** (m - (batch_idx + 1)) / (2 ** m - 1)
    elif beta_type == "Soenderby":
        beta = min(epoch / (num_epochs // 4), 1)
    elif beta_type == "Standard":
        beta = 1 / m
    else:
        beta = 0
    return beta

def elbo(out, y, kl_sum, beta):
    ce_loss = F.cross_entropy(out, y)
    return ce_loss + beta * kl_sum

# %%
loss_fct = nn.NLLLoss(reduce=False)
optimizer = optim.Adam(model.parameters(), lr=float(parameters["hyperparam"]["ff_learning_rate"]))
optimizer
# Out:
# C:\ProgramData\Anaconda3\envs\nn_mal_2\lib\site-packages\torch\nn\_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.01
#     weight_decay: 0
# )

# %%
NumCount = 0
Visited = []

# %%
def train(epoch):
    model.train()
    total_correct = 0.
    total_loss = 0.
    total = 0.

    current_time = time.time()

    if is_synthetic_dataset:
        # since generation of synthetic data set is random, we'd like them to be the same over epochs
        torch.manual_seed(seed_val)
        random.seed(seed_val)
    print("dataloaderr",train_dataloader_dict["benign"].dataset, train_dataloader_dict["malicious"].dataset)
    for batch_idx, ((bon_x, bon_y), (mal_x, mal_y)) in enumerate(
            zip(train_dataloader_dict["benign"], train_dataloader_dict["malicious"])):
        # Check for adversarial learning
        print("This is bacth_idx",batch_idx)
#         print(bon_x)
#         print(bon_y)
#         print(mal_x)
#         print(mal_y)
#         mal_x1 = inner_maximizer(
#             mal_x, mal_y, model, loss_fct, iterations=evasion_iterations, method=training_method)
#         print("THis is mal_X",mal_x1)
        # stack input
#         if is_cuda:
#             x = Variable(stack_tensors(bon_x, mal_x, mal_x1).cuda())
#             y = Variable(stack_tensors(bon_y, mal_y, mal_y).cuda())
#         else:
#             x = Variable(stack_tensors(bon_x, mal_x, mal_x1))
#             y = Variable(stack_tensors(bon_y, mal_y, mal_y))
        x = Variable(stack_tensors(bon_x, mal_x))
        y = Variable(stack_tensors(bon_y, mal_y))
#         print("STACKED")
#         print(x)
#         print(y)
#         print("This is Train Forward Pass",x, y, model )
        
        # forward pass
#         print("FORWARD X")
#         print(x)
        y_model = model(x)
#         print("YMODEL")
#         print(y_model)

        # backward pass
    # batch_idx, m, beta_type, epoch, num_epochs
        optimizer.zero_grad()
        y_model = model(x)
        kl = loss_fct(y_model, y).mean()
        print("BETA VALS")
        print(batch_idx,
                             (train_dataloader_dict["benign"].dataset.__len__() 
                                    + train_dataloader_dict["malicious"].dataset.__len__()),
                            "Blundell",
                            epoch,
                            num_epochs)
        loss = elbo(y_model, y, kl, 
                    get_beta(batch_idx,
                             (train_dataloader_dict["benign"].dataset.__len__() 
                                    + train_dataloader_dict["malicious"].dataset.__len__()),
                            "Blundell",
                            epoch,
                            num_epochs))
        loss.backward()
        optimizer.step()

        # predict pass
        _, predicted = torch.topk(y_model, k=1)
        correct = predicted.data.eq(y.data.view_as(predicted.data)).cpu().sum()

        # metrics
#         print("LOSS LINE 148")
#         print(len(y))
#         print(y)
#         print(total_loss)
#         print(loss.data)
#         print(loss.data.item())
        # total_loss += loss.data[0] * len(y)
        total_loss += loss.data.item() * len(y)

        total_correct += correct
        total += len(y)

        

        if 15%5 == 0:

            print("Time Taken:", time.time() - current_time)
            current_time = time.time()

            print(
                "Train Epoch ({}) | Batch ({}) | [{}/{} ({:.0f}%)]\tBatch Loss: {:.6f}\tBatch Accuracy: {:.1f}%\t BSCN: {:.12f}".
                # format(epoch, batch_idx, batch_idx * len(x),
                #        len(train_dataloader_dict["malicious"].dataset) +
                #        len(train_dataloader_dict["benign"].dataset),
                #        100. * batch_idx / len(train_dataloader_dict["benign"]), loss.data[0],
                #        100. * correct / len(y), bscn.ratio()))
                format(epoch, batch_idx, batch_idx * len(x),
                       len(train_dataloader_dict["malicious"].dataset) +
                       len(train_dataloader_dict["benign"].dataset),
                       100. * batch_idx / len(train_dataloader_dict["benign"]), loss.data.item(),
                       100. * correct / len(y), 1))

# %%
def check_one_category(category="benign", is_validate=False, is_evade=False,
                       evade_method='natural'):
    """
    test the model in terms of loss and accuracy on category, this function also allows to perform perturbation
    with respect to loss to evade
    :param category: benign or malicious dataset
    :param is_validate: validation or testing dataset
    :param is_evade: to perform evasion or not
    :param evade_method: evasion method (we can use on of the inner maximier methods), it is only relevant if is_evade
      is True
    :return:
    """
    model.eval()
    total_loss = 0
    total_correct = 0
    total = 0
    evasion_mode = ""

    if is_synthetic_dataset:
        # since generation of synthetic data set is random, we'd like them to be the same over epochs
        torch.manual_seed(seed_val)
        random.seed(seed_val)

    if is_validate:
        dataloader = valid_dataloader_dict[category]
    else:
        dataloader = test_dataloader_dict[category]

    for batch_idx, (x, y) in enumerate(dataloader):
        #
        if is_evade:
            x = inner_maximizer(
                x, y, model, loss_fct, iterations=evasion_iterations, method='natural')
            evasion_mode = "(evasion using %s)" % evade_method
        # stack input
        if is_cuda:
            x = Variable(x.cuda())
            y = Variable(y.cuda())
        else:
            x = Variable(x)
            y = Variable(y)
#         print("Check one CategoryForward Pass", x, y, model)
        # forward pass
        y_model = model(x)

        # loss pass
        loss = loss_fct(y_model, y).mean()

        # predict pass
        _, predicted = torch.topk(y_model, k=1)
        correct = predicted.data.eq(y.data.view_as(predicted.data)).cpu().sum()

        # metrics
        # total_loss += loss.data[0] * len(y)
        total_loss += loss.data.item() * len(y)
        total_correct += correct
        total += len(y)

    print("{} set for {} {}: Average Loss: {:.4f}, Accuracy: {:.2f}%".format(
        "Valid" if is_validate else "Test", category, evasion_mode, total_loss / total,
        total_correct * 100. / total))

    return total_loss, total_correct, total

# %%
def test(epoch, is_validate=False):
    """
    Function to be used for both testing and validation
    :param epoch: current epoch
    :param is_validate: is the testing done on the validation dataset
    :return: average total loss, dictionary of the metrics for both bon and mal samples
    """
    # test for accuracy and loss
    bon_total_loss, bon_total_correct, bon_total = check_one_category(
        category="benign", is_evade=False, is_validate=is_validate)
    mal_total_loss, mal_total_correct, mal_total = check_one_category(
        category="malicious", is_evade=False, is_validate=is_validate)

    # test for evasion on malicious sample
    evade_mal_total_loss, evade_mal_total_correct, evade_mal_total = check_one_category(
        category="malicious", is_evade=True, evade_method=evasion_method, is_validate=is_validate)

    total_loss = bon_total_loss + mal_total_loss
    total_correct = bon_total_correct + mal_total_correct
    total = bon_total + mal_total

    dataset_type = "valid" if is_validate else "test"

    print("{} set overall: Average Loss: {:.4f}, Accuracy: {:.2f}%".format(
        dataset_type, total_loss / total, total_correct * 100. / total))

    if is_losswise:
        graph_accuracy.append(
            epoch, {
                "%s_accuracy_%s" % (dataset_type, experiment_name): 100. * total_correct / total
            })
        graph_loss.append(epoch, {
            "%s_loss_%s" % (dataset_type, experiment_name): total_loss / total
        })
        graph_evasion.append(
            epoch, {
                "%s_evasion_%s" % (dataset_type, experiment_name):
                100 * (evade_mal_total - evade_mal_total_correct) / evade_mal_total
            })

    metrics = {
        "bscn_ratio": 0,
        "mal": {
            "total_loss": mal_total_loss,
            "total_correct": mal_total_correct,
            "total": mal_total,
            "evasion": {
                "total_loss": evade_mal_total_loss,
                "total_correct": evade_mal_total_correct,
                "total": evade_mal_total
            }
        },
        "bon": {
            "total_loss": bon_total_loss,
            "total_correct": bon_total_correct,
            "total_evade": None,
            "total": bon_total
        }
    }
    print(metrics)

    return (bon_total_loss + max(mal_total_loss, evade_mal_total_loss)) / total, metrics

# %%
_metrics = 0
if __name__ == "__main__":

    if not os.path.exists("result_files"):
        os.mkdir("result_files")

    _metrics = None
    session = None
    if train_model_from_scratch:
        best_valid_loss = float("inf")
        for _epoch in range(num_epochs):
            # train
            train(_epoch)

            # validate
            valid_loss, _ = test(_epoch, is_validate=True)

            # keep the best parameters w.r.t validation and check the test set
            if best_valid_loss > valid_loss:
                best_valid_loss = valid_loss
                _, _metrics = test(_epoch, is_validate=False)

                # torch.save(model, os.path.join("helper_files", "%s-model.pt" % experiment_name))
            elif _epoch % log_interval == 0:
                test(_epoch, is_validate=False)

    else:
        _, _metrics = test(0)

    # with open(os.path.join("result_files", experiment_name + ".json"), "w") as result_file:
    #     json.dump(_metrics, result_file)
    print("METRICS TO DUMP")
    print(_metrics)
# Out:
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 0 10
# Time Taken: 212.33758449554443
# Train Epoch (0) | Batch (0) | [0/540 (0%)]	Batch Loss: 1.041544	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 0 10
# Time Taken: 0.44381284713745117
# Train Epoch (0) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.853141	Batch Accuracy: 62.5%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 0 10
# Time Taken: 0.2812483310699463
# Train Epoch (0) | Batch (2) | [64/540 (12%)]	Batch Loss: 3.825309	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 0 10
# Time Taken: 0.14760589599609375
# Train Epoch (0) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.889034	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 0 10
# Time Taken: 0.02293872833251953
# Train Epoch (0) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.670082	Batch Accuracy: 62.5%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 0 10
# Time Taken: 0.01894998550415039
# Train Epoch (0) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.699888	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 0 10
# Time Taken: 0.019972562789916992
# Train Epoch (0) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.589639	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 0 10
# Time Taken: 0.01895451545715332
# Train Epoch (0) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.735285	Batch Accuracy: 75.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 0 10
# Time Taken: 0.04085898399353027
# Train Epoch (0) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.496039	Batch Accuracy: 71.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 0 10
# Time Taken: 0.2154529094696045
# Train Epoch (0) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.483564	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 0 10
# Time Taken: 0.02892160415649414
# Train Epoch (0) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.435236	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 0 10
# Time Taken: 0.017925500869750977
# Train Epoch (0) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.418389	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 0 10
# Time Taken: 0.016978979110717773
# Train Epoch (0) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.286749	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 0 10
# Time Taken: 0.016927480697631836
# Train Epoch (0) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.694477	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 0 10
# Time Taken: 0.01994776725769043
# Train Epoch (0) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.321791	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 0 10
# Time Taken: 0.01997852325439453
# Train Epoch (0) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.694166	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 0 10
# Time Taken: 0.043851375579833984
# Train Epoch (0) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.263809	Batch Accuracy: 89.3%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.2956, Accuracy: 87.78%
# Valid set for malicious : Average Loss: 0.3451, Accuracy: 90.00%
# Valid set for malicious (evasion using natural): Average Loss: 0.3451, Accuracy: 90.00%
# valid set overall: Average Loss: 0.3203, Accuracy: 88.89%
# {'bscn_ratio': 0, 'mal': {'total_loss': 31.058152318000793, 'total_correct': tensor(81), 'total': 90, 'evasion': {'total_loss': 31.058154046535492, 'total_correct': tensor(81), 'total': 90}}, 'bon': {'total_loss': 26.600728929042816, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}
# Test set for benign : Average Loss: 0.2330, Accuracy: 92.22%
# Test set for malicious : Average Loss: 0.3757, Accuracy: 88.89%
# Test set for malicious (evasion using natural): Average Loss: 0.3757, Accuracy: 88.89%
# test set overall: Average Loss: 0.3044, Accuracy: 90.56%
# {'bscn_ratio': 0, 'mal': {'total_loss': 33.814667880535126, 'total_correct': tensor(80), 'total': 90, 'evasion': {'total_loss': 33.814667880535126, 'total_correct': tensor(80), 'total': 90}}, 'bon': {'total_loss': 20.96998417377472, 'total_correct': tensor(83), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 1 10
# Time Taken: 78.65937733650208
# Train Epoch (1) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.302591	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 1 10
# Time Taken: 0.02593064308166504
# Train Epoch (1) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.278464	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 1 10
# Time Taken: 0.07979202270507812
# Train Epoch (1) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.419765	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 1 10
# Time Taken: 0.025931596755981445
# Train Epoch (1) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.277373	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 1 10
# Time Taken: 0.04288363456726074
# Train Epoch (1) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.137338	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 1 10
# Time Taken: 0.08676743507385254
# Train Epoch (1) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.139191	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 1 10
# Time Taken: 0.12067794799804688
# Train Epoch (1) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.293594	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 1 10
# Time Taken: 0.023935556411743164
# Train Epoch (1) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.267366	Batch Accuracy: 81.2%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 1 10
# Time Taken: 0.028922557830810547
# Train Epoch (1) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.163030	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 1 10
# Time Taken: 0.02393507957458496
# Train Epoch (1) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.096837	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 1 10
# Time Taken: 0.032911062240600586
# Train Epoch (1) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.263858	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 1 10
# Time Taken: 0.07480025291442871
# Train Epoch (1) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.112501	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 1 10
# Time Taken: 0.022938251495361328
# Train Epoch (1) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.125805	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 1 10
# Time Taken: 0.039893388748168945
# Train Epoch (1) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.670105	Batch Accuracy: 81.2%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 1 10
# Time Taken: 0.03390812873840332
# Train Epoch (1) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.186478	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 1 10
# Time Taken: 0.041887760162353516
# Train Epoch (1) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.591696	Batch Accuracy: 81.2%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 1 10
# Time Taken: 0.29620838165283203
# Train Epoch (1) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.189265	Batch Accuracy: 92.9%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.3347, Accuracy: 83.33%
# Valid set for malicious : Average Loss: 0.2863, Accuracy: 94.44%
# Valid set for malicious (evasion using natural): Average Loss: 0.2863, Accuracy: 94.44%
# valid set overall: Average Loss: 0.3105, Accuracy: 88.89%
# {'bscn_ratio': 0, 'mal': {'total_loss': 25.765619575977325, 'total_correct': tensor(85), 'total': 90, 'evasion': {'total_loss': 25.765619933605194, 'total_correct': tensor(85), 'total': 90}}, 'bon': {'total_loss': 30.122085690498352, 'total_correct': tensor(75), 'total_evade': None, 'total': 90}}
# Test set for benign : Average Loss: 0.2599, Accuracy: 87.78%
# Test set for malicious : Average Loss: 0.3614, Accuracy: 91.11%
# Test set for malicious (evasion using natural): Average Loss: 0.3614, Accuracy: 91.11%
# test set overall: Average Loss: 0.3107, Accuracy: 89.44%
# {'bscn_ratio': 0, 'mal': {'total_loss': 32.52846071124077, 'total_correct': tensor(82), 'total': 90, 'evasion': {'total_loss': 32.52846071124077, 'total_correct': tensor(82), 'total': 90}}, 'bon': {'total_loss': 23.391016840934753, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 2 10
# Time Taken: 59.19528269767761
# Train Epoch (2) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.376857	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 2 10
# Time Taken: 0.03789806365966797
# Train Epoch (2) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.191271	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 2 10
# Time Taken: 0.029920339584350586
# Train Epoch (2) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.187812	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 2 10
# Time Taken: 0.06482672691345215
# Train Epoch (2) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.144529	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 2 10
# Time Taken: 0.23537111282348633
# Train Epoch (2) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.250753	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 2 10
# Time Taken: 0.44580745697021484
# Train Epoch (2) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.068919	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 2 10
# Time Taken: 0.028921842575073242
# Train Epoch (2) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.064159	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 2 10
# Time Taken: 0.032912254333496094
# Train Epoch (2) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.084112	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 2 10
# Time Taken: 0.027925491333007812
# Train Epoch (2) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.178392	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 2 10
# Time Taken: 0.026927709579467773
# Train Epoch (2) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.050297	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 2 10
# Time Taken: 0.08477258682250977
# Train Epoch (2) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.200063	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 2 10
# Time Taken: 0.03391098976135254
# Train Epoch (2) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.078629	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 2 10
# Time Taken: 0.031914472579956055
# Train Epoch (2) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.051338	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 2 10
# Time Taken: 0.030916213989257812
# Train Epoch (2) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.166667	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 2 10
# Time Taken: 0.027927875518798828
# Train Epoch (2) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.138206	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 2 10
# Time Taken: 0.02592921257019043
# Train Epoch (2) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.038531	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 2 10
# Time Taken: 0.027924060821533203
# Train Epoch (2) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.064071	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 1.4308, Accuracy: 82.22%
# Valid set for malicious : Average Loss: 0.1966, Accuracy: 96.67%
# Valid set for malicious (evasion using natural): Average Loss: 0.1966, Accuracy: 96.67%
# valid set overall: Average Loss: 0.8137, Accuracy: 89.44%
# {'bscn_ratio': 0, 'mal': {'total_loss': 17.697526570409536, 'total_correct': tensor(87), 'total': 90, 'evasion': {'total_loss': 17.697525709867477, 'total_correct': tensor(87), 'total': 90}}, 'bon': {'total_loss': 128.76991271972656, 'total_correct': tensor(74), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 3 10
# Time Taken: 59.27728199958801
# Train Epoch (3) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.117540	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 3 10
# Time Taken: 0.08178043365478516
# Train Epoch (3) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.066247	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 3 10
# Time Taken: 0.06781888008117676
# Train Epoch (3) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.096297	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 3 10
# Time Taken: 0.04587602615356445
# Train Epoch (3) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.038739	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 3 10
# Time Taken: 0.04886889457702637
# Train Epoch (3) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.032341	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 3 10
# Time Taken: 0.06682205200195312
# Train Epoch (3) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.179126	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 3 10
# Time Taken: 0.03091740608215332
# Train Epoch (3) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.065479	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 3 10
# Time Taken: 0.029918670654296875
# Train Epoch (3) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.043180	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 3 10
# Time Taken: 0.03191566467285156
# Train Epoch (3) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.036565	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 3 10
# Time Taken: 0.028922080993652344
# Train Epoch (3) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.124340	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 3 10
# Time Taken: 0.030918359756469727
# Train Epoch (3) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.071593	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 3 10
# Time Taken: 0.029919862747192383
# Train Epoch (3) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.027741	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 3 10
# Time Taken: 0.028922080993652344
# Train Epoch (3) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.220070	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 3 10
# Time Taken: 0.023935317993164062
# Train Epoch (3) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.088490	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 3 10
# Time Taken: 0.026927947998046875
# Train Epoch (3) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.757190	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 3 10
# Time Taken: 0.02593064308166504
# Train Epoch (3) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.060431	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 3 10
# Time Taken: 0.026927947998046875
# Train Epoch (3) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.057541	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.7626, Accuracy: 87.78%
# Valid set for malicious : Average Loss: 0.6628, Accuracy: 80.00%
# Valid set for malicious (evasion using natural): Average Loss: 0.6628, Accuracy: 80.00%
# valid set overall: Average Loss: 0.7127, Accuracy: 83.89%
# {'bscn_ratio': 0, 'mal': {'total_loss': 59.648988366127014, 'total_correct': tensor(72), 'total': 90, 'evasion': {'total_loss': 59.64898753166199, 'total_correct': tensor(72), 'total': 90}}, 'bon': {'total_loss': 68.63622213900089, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 4 10
# Time Taken: 59.926204442977905
# Train Epoch (4) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.093394	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 4 10
# Time Taken: 0.02892303466796875
# Train Epoch (4) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.134909	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 4 10
# Time Taken: 0.02393484115600586
# Train Epoch (4) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.064441	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 4 10
# Time Taken: 0.040891170501708984
# Train Epoch (4) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.064793	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 4 10
# Time Taken: 0.024935007095336914
# Train Epoch (4) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.077547	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 4 10
# Time Taken: 0.029920578002929688
# Train Epoch (4) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.076695	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 4 10
# Time Taken: 0.027924060821533203
# Train Epoch (4) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.028832	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 4 10
# Time Taken: 0.022940397262573242
# Train Epoch (4) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.080903	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 4 10
# Time Taken: 0.035904645919799805
# Train Epoch (4) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.096430	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 4 10
# Time Taken: 0.020942211151123047
# Train Epoch (4) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.033622	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 4 10
# Time Taken: 0.025930404663085938
# Train Epoch (4) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.032069	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 4 10
# Time Taken: 0.020944833755493164
# Train Epoch (4) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.092076	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 4 10
# Time Taken: 0.03989362716674805
# Train Epoch (4) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.075802	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 4 10
# Time Taken: 0.024938344955444336
# Train Epoch (4) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.016550	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 4 10
# Time Taken: 0.02194833755493164
# Train Epoch (4) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.181698	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 4 10
# Time Taken: 0.022936582565307617
# Train Epoch (4) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.035292	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 4 10
# Time Taken: 0.020943641662597656
# Train Epoch (4) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.223539	Batch Accuracy: 89.3%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 1.2708, Accuracy: 82.22%
# Valid set for malicious : Average Loss: 0.5012, Accuracy: 95.56%
# Valid set for malicious (evasion using natural): Average Loss: 0.5012, Accuracy: 95.56%
# valid set overall: Average Loss: 0.8860, Accuracy: 88.89%
# {'bscn_ratio': 0, 'mal': {'total_loss': 45.111171662807465, 'total_correct': tensor(86), 'total': 90, 'evasion': {'total_loss': 45.11116962134838, 'total_correct': tensor(86), 'total': 90}}, 'bon': {'total_loss': 114.36901099979877, 'total_correct': tensor(74), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 5 10
# Time Taken: 60.23089575767517
# Train Epoch (5) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.086380	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 5 10
# Time Taken: 0.024932384490966797
# Train Epoch (5) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.077859	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 5 10
# Time Taken: 0.021941423416137695
# Train Epoch (5) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.044092	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 5 10
# Time Taken: 0.015956878662109375
# Train Epoch (5) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.061853	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 5 10
# Time Taken: 0.019945859909057617
# Train Epoch (5) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.035306	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 5 10
# Time Taken: 0.017953157424926758
# Train Epoch (5) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.081666	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 5 10
# Time Taken: 0.016954421997070312
# Train Epoch (5) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.001067	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 5 10
# Time Taken: 0.022937536239624023
# Train Epoch (5) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.099142	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 5 10
# Time Taken: 0.01997542381286621
# Train Epoch (5) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.037308	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 5 10
# Time Taken: 0.018948793411254883
# Train Epoch (5) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.059676	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 5 10
# Time Taken: 0.019948720932006836
# Train Epoch (5) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.001060	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 5 10
# Time Taken: 0.021940231323242188
# Train Epoch (5) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.056674	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 5 10
# Time Taken: 0.023935556411743164
# Train Epoch (5) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.036431	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 5 10
# Time Taken: 0.025930404663085938
# Train Epoch (5) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.015293	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 5 10
# Time Taken: 0.024933576583862305
# Train Epoch (5) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.042315	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 5 10
# Time Taken: 0.021942615509033203
# Train Epoch (5) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.005050	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 5 10
# Time Taken: 0.023934125900268555
# Train Epoch (5) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.016416	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 1.4393, Accuracy: 86.67%
# Valid set for malicious : Average Loss: 0.9858, Accuracy: 92.22%
# Valid set for malicious (evasion using natural): Average Loss: 0.9858, Accuracy: 92.22%
# valid set overall: Average Loss: 1.2125, Accuracy: 89.44%
# {'bscn_ratio': 0, 'mal': {'total_loss': 88.71825554966927, 'total_correct': tensor(83), 'total': 90, 'evasion': {'total_loss': 88.71825298666954, 'total_correct': tensor(83), 'total': 90}}, 'bon': {'total_loss': 129.53336691856384, 'total_correct': tensor(78), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 6 10
# Time Taken: 60.81768321990967
# Train Epoch (6) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.000284	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 6 10
# Time Taken: 0.056847333908081055
# Train Epoch (6) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.269749	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 6 10
# Time Taken: 0.03390932083129883
# Train Epoch (6) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.060858	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 6 10
# Time Taken: 0.029920101165771484
# Train Epoch (6) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.030016	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 6 10
# Time Taken: 0.020945072174072266
# Train Epoch (6) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.579124	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 6 10
# Time Taken: 0.020945310592651367
# Train Epoch (6) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.067757	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 6 10
# Time Taken: 0.022938013076782227
# Train Epoch (6) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.000917	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 6 10
# Time Taken: 0.02592921257019043
# Train Epoch (6) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.036388	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 6 10
# Time Taken: 0.02493429183959961
# Train Epoch (6) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.377065	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 6 10
# Time Taken: 0.022936582565307617
# Train Epoch (6) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.370493	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 6 10
# Time Taken: 0.02692866325378418
# Train Epoch (6) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.016641	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 6 10
# Time Taken: 0.02393627166748047
# Train Epoch (6) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.076146	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 6 10
# Time Taken: 0.0608365535736084
# Train Epoch (6) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.061121	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 6 10
# Time Taken: 0.021944522857666016
# Train Epoch (6) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.037960	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 6 10
# Time Taken: 0.023935794830322266
# Train Epoch (6) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.049320	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 6 10
# Time Taken: 0.021943092346191406
# Train Epoch (6) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.066939	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 6 10
# Time Taken: 0.025931119918823242
# Train Epoch (6) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.110095	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.4668, Accuracy: 87.78%
# Valid set for malicious : Average Loss: 0.3635, Accuracy: 87.78%
# Valid set for malicious (evasion using natural): Average Loss: 0.3635, Accuracy: 87.78%
# valid set overall: Average Loss: 0.4151, Accuracy: 87.78%
# {'bscn_ratio': 0, 'mal': {'total_loss': 32.712795436382294, 'total_correct': tensor(79), 'total': 90, 'evasion': {'total_loss': 32.712796211242676, 'total_correct': tensor(79), 'total': 90}}, 'bon': {'total_loss': 42.00935357809067, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 7 10
# Time Taken: 65.08056569099426
# Train Epoch (7) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.153457	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 7 10
# Time Taken: 0.027924537658691406
# Train Epoch (7) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.188196	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 7 10
# Time Taken: 0.027927160263061523
# Train Epoch (7) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.031790	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 7 10
# Time Taken: 0.04089045524597168
# Train Epoch (7) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.124841	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 7 10
# Time Taken: 0.021941184997558594
# Train Epoch (7) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.026935	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 7 10
# Time Taken: 0.021943092346191406
# Train Epoch (7) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.048940	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 7 10
# Time Taken: 0.021941423416137695
# Train Epoch (7) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.034086	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 7 10
# Time Taken: 0.024932861328125
# Train Epoch (7) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.027709	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 7 10
# Time Taken: 0.05186176300048828
# Train Epoch (7) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.024029	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 7 10
# Time Taken: 0.0219419002532959
# Train Epoch (7) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.009565	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 7 10
# Time Taken: 0.019947052001953125
# Train Epoch (7) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.016372	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 7 10
# Time Taken: 0.0249326229095459
# Train Epoch (7) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.034301	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 7 10
# Time Taken: 0.02393651008605957
# Train Epoch (7) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.015409	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 7 10
# Time Taken: 0.022937774658203125
# Train Epoch (7) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.000471	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 7 10
# Time Taken: 0.03390932083129883
# Train Epoch (7) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.063344	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 7 10
# Time Taken: 0.024933338165283203
# Train Epoch (7) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.000028	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 7 10
# Time Taken: 0.02293872833251953
# Train Epoch (7) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.000002	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 3.7985, Accuracy: 84.44%
# Valid set for malicious : Average Loss: 1.0038, Accuracy: 92.22%
# Valid set for malicious (evasion using natural): Average Loss: 1.0038, Accuracy: 92.22%
# valid set overall: Average Loss: 2.4012, Accuracy: 88.33%
# {'bscn_ratio': 0, 'mal': {'total_loss': 90.34018698334694, 'total_correct': tensor(83), 'total': 90, 'evasion': {'total_loss': 90.34019051492214, 'total_correct': tensor(83), 'total': 90}}, 'bon': {'total_loss': 341.86833429125545, 'total_correct': tensor(76), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 8 10
# Time Taken: 59.50536346435547
# Train Epoch (8) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.011404	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 8 10
# Time Taken: 0.027926206588745117
# Train Epoch (8) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.011404	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 8 10
# Time Taken: 0.027924776077270508
# Train Epoch (8) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.000037	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 8 10
# Time Taken: 0.027925729751586914
# Train Epoch (8) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.002199	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 8 10
# Time Taken: 0.026927947998046875
# Train Epoch (8) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.000247	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 8 10
# Time Taken: 0.021942853927612305
# Train Epoch (8) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.000021	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 8 10
# Time Taken: 0.023935556411743164
# Train Epoch (8) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.520630	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 8 10
# Time Taken: 0.03191542625427246
# Train Epoch (8) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.152383	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 8 10
# Time Taken: 0.024933338165283203
# Train Epoch (8) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.000202	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 8 10
# Time Taken: 0.021941184997558594
# Train Epoch (8) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.079656	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 8 10
# Time Taken: 0.02393507957458496
# Train Epoch (8) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.025078	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 8 10
# Time Taken: 0.027925968170166016
# Train Epoch (8) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.027412	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 8 10
# Time Taken: 0.02393627166748047
# Train Epoch (8) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.042055	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 8 10
# Time Taken: 0.022940635681152344
# Train Epoch (8) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.516833	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 8 10
# Time Taken: 0.028921127319335938
# Train Epoch (8) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.089586	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 8 10
# Time Taken: 0.024932146072387695
# Train Epoch (8) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.030879	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 8 10
# Time Taken: 0.020943880081176758
# Train Epoch (8) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.000037	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 2.3654, Accuracy: 85.56%
# Valid set for malicious : Average Loss: 0.8830, Accuracy: 87.78%
# Valid set for malicious (evasion using natural): Average Loss: 0.8830, Accuracy: 87.78%
# valid set overall: Average Loss: 1.6242, Accuracy: 86.67%
# {'bscn_ratio': 0, 'mal': {'total_loss': 79.4708446264267, 'total_correct': tensor(79), 'total': 90, 'evasion': {'total_loss': 79.47084705531597, 'total_correct': tensor(79), 'total': 90}}, 'bon': {'total_loss': 212.88344777032034, 'total_correct': tensor(77), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x0000019832FDD588> <datasets.datasets.PortableExecutableDataset object at 0x0000019830BBC9B0>
# This is bacth_idx 0
# BETA VALS
# 0 540 Blundell 9 10
# Time Taken: 57.695549726486206
# Train Epoch (9) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.000263	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Blundell 9 10
# Time Taken: 0.026927709579467773
# Train Epoch (9) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.024193	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Blundell 9 10
# Time Taken: 0.02593064308166504
# Train Epoch (9) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.125970	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Blundell 9 10
# Time Taken: 0.020944595336914062
# Train Epoch (9) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.056063	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Blundell 9 10
# Time Taken: 0.020943880081176758
# Train Epoch (9) | Batch (4) | [128/540 (24%)]	Batch Loss: 1.252931	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Blundell 9 10
# Time Taken: 0.027926206588745117
# Train Epoch (9) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.151313	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Blundell 9 10
# Time Taken: 0.022938251495361328
# Train Epoch (9) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.024180	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Blundell 9 10
# Time Taken: 0.0249330997467041
# Train Epoch (9) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.039977	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Blundell 9 10
# Time Taken: 0.019947290420532227
# Train Epoch (9) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.034001	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Blundell 9 10
# Time Taken: 0.029919862747192383
# Train Epoch (9) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.044347	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Blundell 9 10
# Time Taken: 0.028923511505126953
# Train Epoch (9) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.096430	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Blundell 9 10
# Time Taken: 0.01894998550415039
# Train Epoch (9) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.062404	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Blundell 9 10
# Time Taken: 0.028890371322631836
# Train Epoch (9) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.183582	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Blundell 9 10
# Time Taken: 0.018947839736938477
# Train Epoch (9) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.034273	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Blundell 9 10
# Time Taken: 0.017951488494873047
# Train Epoch (9) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.050507	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Blundell 9 10
# Time Taken: 0.01894974708557129
# Train Epoch (9) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.065219	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Blundell 9 10
# Time Taken: 0.021941661834716797
# Train Epoch (9) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.047664	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.5048, Accuracy: 88.89%
# Valid set for malicious : Average Loss: 0.6751, Accuracy: 91.11%
# Valid set for malicious (evasion using natural): Average Loss: 0.6751, Accuracy: 91.11%
# valid set overall: Average Loss: 0.5900, Accuracy: 90.00%
# {'bscn_ratio': 0, 'mal': {'total_loss': 60.75656259059906, 'total_correct': tensor(82), 'total': 90, 'evasion': {'total_loss': 60.756564259529114, 'total_correct': tensor(82), 'total': 90}}, 'bon': {'total_loss': 45.4347968432121, 'total_correct': tensor(80), 'total_evade': None, 'total': 90}}
# METRICS TO DUMP
# {'bscn_ratio': 0, 'mal': {'total_loss': 32.52846071124077, 'total_correct': tensor(82), 'total': 90, 'evasion': {'total_loss': 32.52846071124077, 'total_correct': tensor(82), 'total': 90}}, 'bon': {'total_loss': 23.391016840934753, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}

# %%
type(_metrics)
# Out:
# dict

# %%
_metrics
# Out:
# {'bscn_ratio': 0,
#  'mal': {'total_loss': 32.52846071124077,
#   'total_correct': tensor(82),
#   'total': 90,
#   'evasion': {'total_loss': 32.52846071124077,
#    'total_correct': tensor(82),
#    'total': 90}},
#  'bon': {'total_loss': 23.391016840934753,
#   'total_correct': tensor(79),
#   'total_evade': None,
#   'total': 90}}

# %%
_metrics['mal']['total']
# Out:
# 90

# %%
def confMat(_metrics):
    total_mal = _metrics['mal']['total']
    total_mal_correct = _metrics['mal']['total_correct']
    total_mal_wrong = total_mal - total_mal_correct
    
    total_ben = _metrics['bon']['total']
    total_ben_correct = _metrics['bon']['total_correct']
    total_ben_wrong = total_ben - total_ben_correct
    
    true_list = []
    for i in range(total_mal):
        true_list.append(1)
    for i in range(total_ben):
        true_list.append(0)
        
    pred_list = []
    for i in range(total_mal_correct):
        pred_list.append(1)
    for i in range(total_mal_wrong):
        pred_list.append(0)
    for i in range(total_ben_correct):
        pred_list.append(0)
    for i in range(total_ben_wrong):
        pred_list.append(1)
    return true_list,pred_list

# %%
TrueList,PredList = confMat(_metrics)

# %%
np.unique(np.array(TrueList),return_counts=True)
# Out:
# (array([0, 1]), array([90, 90], dtype=int64))

# %%
np.unique(np.array(PredList),return_counts=True)
# Out:
# (array([0, 1]), array([87, 93], dtype=int64))

# %%
from sklearn import metrics

# %%
print(metrics.confusion_matrix(TrueList,PredList))
# Out:
# [[79 11]
#  [ 8 82]]

# %%
print(metrics.classification_report(TrueList,PredList))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89        90
#            1       0.88      0.91      0.90        90
#
#     accuracy                           0.89       180
#    macro avg       0.89      0.89      0.89       180
# weighted avg       0.89      0.89      0.89       180
