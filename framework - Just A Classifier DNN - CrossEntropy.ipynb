# %%
import os
import torch
import random
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from utils.utils import load_parameters, stack_tensors
from datasets.datasets import load_data
from inner_maximizers.inner_maximizers import inner_maximizer
from nets.ff_classifier import build_ff_classifier
import losswise
import time
import json
import numpy as np

# %%
parameters = load_parameters("parameters.ini")
is_cuda = eval(parameters["general"]["is_cuda"])
if is_cuda:
    os.environ["CUDA_VISIBLE_DEVICES"] = parameters["general"]["gpu_device"]

assertion_message = "Set this flag off to train models."
assert eval(parameters['dataset']['generate_feature_vector_files']) is False, assertion_message

log_interval = int(parameters["general"]["log_interval"])
num_epochs = int(parameters["hyperparam"]["ff_num_epochs"])
is_losswise = eval(parameters["general"]["is_losswise"])
is_synthetic_dataset = eval(parameters["general"]["is_synthetic_dataset"])

training_method = parameters["general"]["training_method"]
evasion_method = parameters["general"]["evasion_method"]
experiment_suffix = parameters["general"]["experiment_suffix"]
experiment_name = "[training:%s|evasion:%s]_%s" % (training_method, evasion_method,
                                                   experiment_suffix)

print("Training Method:%s, Evasion Method:%s" % (training_method, evasion_method))

seed_val = int(parameters["general"]["seed"])

random.seed(seed_val)
torch.manual_seed(seed_val)
np.random.seed(seed_val)
# Out:
# Training Method:rfgsm_k, Evasion Method:natural

# %%
evasion_iterations = int(parameters['hyperparam']['evasion_iterations'])

save_every_epoch = eval(parameters['general']['save_every_epoch'])

train_model_from_scratch = eval(parameters['general']['train_model_from_scratch'])
load_model_weights = eval(parameters['general']['load_model_weights'])
model_weights_path = parameters['general']['model_weights_path']

# %%
train_dataloader_dict, valid_dataloader_dict, test_dataloader_dict, num_features = load_data(
    parameters)
# Out:
# Starting data loading
# Creating import to index mapping
# -- accessing file: ./helper_files/N5000/pmal/
# -- accessing file: ./helper_files/N5000/pben/
# Malicious files: 500
# Benign files: 500
# Total number of files: 1000
# 0 Time: 0.0  seconds
# 100 Time: 0.0696408748626709  seconds
# 200 Time: 0.06705093383789062  seconds
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# ...
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# -- accessing file: ./helper_files/None.txt
# -- accessing file: ./helper_files/N5000/pmal/
# -- accessing file: ./helper_files/N5000/pben/
# Malware Files: 450
# Benign Files: 450
# Preparing training datasets
# Preparing validation datasets
# Preparing testing datasets
# FAL
# ./helper_files/N5000/pmal/Pickle_malware198.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign479.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware5.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign204.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware5.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign479.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware198.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign204.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware247.pt
# FV
# tensor([0., 0., 1.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign228.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware247.pt
# FV
# tensor([0., 0., 1.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign479.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign479.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# This is trainMalicious ['./helper_files/N5000/pmal/Pickle_malware0.pt', './helper_files/N5000/pmal/Pickle_malware1.pt', './helper_files/N5000/pmal/Pickle_malware10.pt', './helper_files/N5000/pmal/Pickle_malware100.pt', './helper_files/N5000/pmal/Pickle_malware101.pt', './helper_files/N5000/pmal/Pickle_malware102.pt', './helper_files/N5000/pmal/Pickle_malware103.pt', './helper_files/N5000/pmal/Pickle_malware104.pt', './helper_files/N5000/pmal/Pickle_malware105.pt', './helper_files/N5000/pmal/Pickle_malware106.pt', './helper_files/N5000/pmal/Pickle_malware107.pt', './helper_files/N5000/pmal/Pickle_malware108.pt', './helper_files/N5000/pmal/Pickle_malware109.pt', './helper_files/N5000/pmal/Pickle_malware11.pt', './helper_files/N5000/pmal/Pickle_malware110.pt', './helper_files/N5000/pmal/Pickle_malware111.pt', './helper_files/N5000/pmal/Pickle_malware112.pt', './helper_files/N5000/pmal/Pickle_malware113.pt', './helper_files/N5000/pmal/Pickle_malware114.pt', './helper_files/N5000/pmal/Pickle_malware115.pt', './helper_files/N5000/pmal/Pickle_malware116.pt', './helper_files/N5000/pmal/Pickle_malware117.pt', './helper_files/N5000/pmal/Pickle_malware118.pt', './helper_files/N5000/pmal/Pickle_malware119.pt', './helper_files/N5000/pmal/Pickle_malware12.pt', './helper_files/N5000/pmal/Pickle_malware120.pt', './helper_files/N5000/pmal/Pickle_malware121.pt', './helper_files/N5000/pmal/Pickle_malware122.pt', './helper_files/N5000/pmal/Pickle_malware123.pt', './helper_files/N5000/pmal/Pickle_malware124.pt', './helper_files/N5000/pmal/Pickle_malware125.pt', './helper_files/N5000/pmal/Pickle_malware126.pt', './helper_files/N5000/pmal/Pickle_malware127.pt', './helper_files/N5000/pmal/Pickle_malware128.pt', './helper_files/N5000/pmal/Pickle_malware129.pt', './helper_files/N5000/pmal/Pickle_malware13.pt', './helper_files/N5000/pmal/Pickle_malware130.pt', './helper_files/N5000/pmal/Pickle_malware131.pt', './helper_files/N5000/pmal/Pickle_malware132.pt', './helper_files/N5000/pmal/Pickle_malware133.pt', './helper_files/N5000/pmal/Pickle_malware134.pt', './helper_files/N5000/pmal/Pickle_malware135.pt', './helper_files/N5000/pmal/Pickle_malware136.pt', './helper_files/N5000/pmal/Pickle_malware137.pt', './helper_files/N5000/pmal/Pickle_malware138.pt', './helper_files/N5000/pmal/Pickle_malware139.pt', './helper_files/N5000/pmal/Pickle_malware14.pt', './helper_files/N5000/pmal/Pickle_malware140.pt', './helper_files/N5000/pmal/Pickle_malware141.pt', './helper_files/N5000/pmal/Pickle_malware142.pt', './helper_files/N5000/pmal/Pickle_malware143.pt', './helper_files/N5000/pmal/Pickle_malware144.pt', './helper_files/N5000/pmal/Pickle_malware145.pt', './helper_files/N5000/pmal/Pickle_malware146.pt', './helper_files/N5000/pmal/Pickle_malware147.pt', './helper_files/N5000/pmal/Pickle_malware148.pt', './helper_files/N5000/pmal/Pickle_malware149.pt', './helper_files/N5000/pmal/Pickle_malware15.pt', './helper_files/N5000/pmal/Pickle_malware150.pt', './helper_files/N5000/pmal/Pickle_malware151.pt', './helper_files/N5000/pmal/Pickle_malware152.pt', './helper_files/N5000/pmal/Pickle_malware153.pt', './helper_files/N5000/pmal/Pickle_malware154.pt', './helper_files/N5000/pmal/Pickle_malware155.pt', './helper_files/N5000/pmal/Pickle_malware156.pt', './helper_files/N5000/pmal/Pickle_malware157.pt', './helper_files/N5000/pmal/Pickle_malware158.pt', './helper_files/N5000/pmal/Pickle_malware159.pt', './helper_files/N5000/pmal/Pickle_malware16.pt', './helper_files/N5000/pmal/Pickle_malware160.pt', './helper_files/N5000/pmal/Pickle_malware161.pt', './helper_files/N5000/pmal/Pickle_malware162.pt', './helper_files/N5000/pmal/Pickle_malware163.pt', './helper_files/N5000/pmal/Pickle_malware164.pt', './helper_files/N5000/pmal/Pickle_malware165.pt', './helper_files/N5000/pmal/Pickle_malware166.pt', './helper_files/N5000/pmal/Pickle_malware167.pt', './helper_files/N5000/pmal/Pickle_malware168.pt', './helper_files/N5000/pmal/Pickle_malware169.pt', './helper_files/N5000/pmal/Pickle_mal ...

# %%
num_samples = len(train_dataloader_dict["malicious"].dataset)

# %%
model = build_ff_classifier(
        input_size=num_features,
        hidden_1_size=int(parameters["hyperparam"]["ff_h1"]),
        hidden_2_size=int(parameters["hyperparam"]["ff_h2"]),
        hidden_3_size=int(parameters["hyperparam"]["ff_h3"]))
model
# Out:
# Sequential(
#   (0): Linear(in_features=2948, out_features=300, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=300, out_features=300, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=300, out_features=300, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=300, out_features=2, bias=True)
#   (7): LogSoftmax(dim=1)
# )

# %%
loss_fct = nn.NLLLoss(reduce=False)
optimizer = optim.Adam(model.parameters(), lr=float(parameters["hyperparam"]["ff_learning_rate"]))
optimizer
# Out:
# C:\ProgramData\Anaconda3\envs\nn_mal_2\lib\site-packages\torch\nn\_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.01
#     weight_decay: 0
# )

# %%
NumCount = 0
Visited = []

# %%
def train(epoch):
    model.train()
    total_correct = 0.
    total_loss = 0.
    total = 0.

    current_time = time.time()

    if is_synthetic_dataset:
        # since generation of synthetic data set is random, we'd like them to be the same over epochs
        torch.manual_seed(seed_val)
        random.seed(seed_val)
    print("dataloaderr",train_dataloader_dict["benign"].dataset, train_dataloader_dict["malicious"].dataset)
    for batch_idx, ((bon_x, bon_y), (mal_x, mal_y)) in enumerate(
            zip(train_dataloader_dict["benign"], train_dataloader_dict["malicious"])):
        # Check for adversarial learning
        print("This is bacth_idx",batch_idx)
#         print(bon_x)
#         print(bon_y)
#         print(mal_x)
#         print(mal_y)
#         mal_x1 = inner_maximizer(
#             mal_x, mal_y, model, loss_fct, iterations=evasion_iterations, method=training_method)
#         print("THis is mal_X",mal_x1)
        # stack input
#         if is_cuda:
#             x = Variable(stack_tensors(bon_x, mal_x, mal_x1).cuda())
#             y = Variable(stack_tensors(bon_y, mal_y, mal_y).cuda())
#         else:
#             x = Variable(stack_tensors(bon_x, mal_x, mal_x1))
#             y = Variable(stack_tensors(bon_y, mal_y, mal_y))
        x = Variable(stack_tensors(bon_x, mal_x))
        y = Variable(stack_tensors(bon_y, mal_y))
#         print("STACKED")
#         print(x)
#         print(y)
#         print("This is Train Forward Pass",x, y, model )
        
        # forward pass
#         print("FORWARD X")
#         print(x)
        y_model = model(x)
#         print("YMODEL")
#         print(y_model)

        # backward pass
        optimizer.zero_grad()
#         print("LOSS VARS")
#         print("YHAT")
#         print(y_model)
#         print("Y")
#         print(y)
        loss = loss_fct(y_model, y).mean()
        loss.backward()
        optimizer.step()

        # predict pass
        _, predicted = torch.topk(y_model, k=1)
        correct = predicted.data.eq(y.data.view_as(predicted.data)).cpu().sum()

        # metrics
#         print("LOSS LINE 148")
#         print(len(y))
#         print(y)
#         print(total_loss)
#         print(loss.data)
#         print(loss.data.item())
        # total_loss += loss.data[0] * len(y)
        total_loss += loss.data.item() * len(y)

        total_correct += correct
        total += len(y)

        

        if 15%5 == 0:

            print("Time Taken:", time.time() - current_time)
            current_time = time.time()

            print(
                "Train Epoch ({}) | Batch ({}) | [{}/{} ({:.0f}%)]\tBatch Loss: {:.6f}\tBatch Accuracy: {:.1f}%\t BSCN: {:.12f}".
                # format(epoch, batch_idx, batch_idx * len(x),
                #        len(train_dataloader_dict["malicious"].dataset) +
                #        len(train_dataloader_dict["benign"].dataset),
                #        100. * batch_idx / len(train_dataloader_dict["benign"]), loss.data[0],
                #        100. * correct / len(y), bscn.ratio()))
                format(epoch, batch_idx, batch_idx * len(x),
                       len(train_dataloader_dict["malicious"].dataset) +
                       len(train_dataloader_dict["benign"].dataset),
                       100. * batch_idx / len(train_dataloader_dict["benign"]), loss.data.item(),
                       100. * correct / len(y), 1))

# %%
def check_one_category(category="benign", is_validate=False, is_evade=False,
                       evade_method='natural'):
    """
    test the model in terms of loss and accuracy on category, this function also allows to perform perturbation
    with respect to loss to evade
    :param category: benign or malicious dataset
    :param is_validate: validation or testing dataset
    :param is_evade: to perform evasion or not
    :param evade_method: evasion method (we can use on of the inner maximier methods), it is only relevant if is_evade
      is True
    :return:
    """
    model.eval()
    total_loss = 0
    total_correct = 0
    total = 0
    evasion_mode = ""

    if is_synthetic_dataset:
        # since generation of synthetic data set is random, we'd like them to be the same over epochs
        torch.manual_seed(seed_val)
        random.seed(seed_val)

    if is_validate:
        dataloader = valid_dataloader_dict[category]
    else:
        dataloader = test_dataloader_dict[category]

    for batch_idx, (x, y) in enumerate(dataloader):
        #
        if is_evade:
            x = inner_maximizer(
                x, y, model, loss_fct, iterations=evasion_iterations, method='natural')
            evasion_mode = "(evasion using %s)" % evade_method
        # stack input
        if is_cuda:
            x = Variable(x.cuda())
            y = Variable(y.cuda())
        else:
            x = Variable(x)
            y = Variable(y)
#         print("Check one CategoryForward Pass", x, y, model)
        # forward pass
        y_model = model(x)

        # loss pass
        loss = loss_fct(y_model, y).mean()

        # predict pass
        _, predicted = torch.topk(y_model, k=1)
        correct = predicted.data.eq(y.data.view_as(predicted.data)).cpu().sum()

        # metrics
        # total_loss += loss.data[0] * len(y)
        total_loss += loss.data.item() * len(y)
        total_correct += correct
        total += len(y)

    print("{} set for {} {}: Average Loss: {:.4f}, Accuracy: {:.2f}%".format(
        "Valid" if is_validate else "Test", category, evasion_mode, total_loss / total,
        total_correct * 100. / total))

    return total_loss, total_correct, total

# %%
def test(epoch, is_validate=False):
    """
    Function to be used for both testing and validation
    :param epoch: current epoch
    :param is_validate: is the testing done on the validation dataset
    :return: average total loss, dictionary of the metrics for both bon and mal samples
    """
    # test for accuracy and loss
    bon_total_loss, bon_total_correct, bon_total = check_one_category(
        category="benign", is_evade=False, is_validate=is_validate)
    mal_total_loss, mal_total_correct, mal_total = check_one_category(
        category="malicious", is_evade=False, is_validate=is_validate)

    # test for evasion on malicious sample
    evade_mal_total_loss, evade_mal_total_correct, evade_mal_total = check_one_category(
        category="malicious", is_evade=True, evade_method=evasion_method, is_validate=is_validate)

    total_loss = bon_total_loss + mal_total_loss
    total_correct = bon_total_correct + mal_total_correct
    total = bon_total + mal_total

    dataset_type = "valid" if is_validate else "test"

    print("{} set overall: Average Loss: {:.4f}, Accuracy: {:.2f}%".format(
        dataset_type, total_loss / total, total_correct * 100. / total))

    if is_losswise:
        graph_accuracy.append(
            epoch, {
                "%s_accuracy_%s" % (dataset_type, experiment_name): 100. * total_correct / total
            })
        graph_loss.append(epoch, {
            "%s_loss_%s" % (dataset_type, experiment_name): total_loss / total
        })
        graph_evasion.append(
            epoch, {
                "%s_evasion_%s" % (dataset_type, experiment_name):
                100 * (evade_mal_total - evade_mal_total_correct) / evade_mal_total
            })

    metrics = {
        "bscn_ratio": 0,
        "mal": {
            "total_loss": mal_total_loss,
            "total_correct": mal_total_correct,
            "total": mal_total,
            "evasion": {
                "total_loss": evade_mal_total_loss,
                "total_correct": evade_mal_total_correct,
                "total": evade_mal_total
            }
        },
        "bon": {
            "total_loss": bon_total_loss,
            "total_correct": bon_total_correct,
            "total_evade": None,
            "total": bon_total
        }
    }
    print(metrics)

    return (bon_total_loss + max(mal_total_loss, evade_mal_total_loss)) / total, metrics

# %%
_metrics = 0
if __name__ == "__main__":

    if not os.path.exists("result_files"):
        os.mkdir("result_files")

    _metrics = None
    session = None
    if train_model_from_scratch:
        best_valid_loss = float("inf")
        for _epoch in range(num_epochs):
            # train
            train(_epoch)

            # validate
            valid_loss, _ = test(_epoch, is_validate=True)

            # keep the best parameters w.r.t validation and check the test set
            if best_valid_loss > valid_loss:
                best_valid_loss = valid_loss
                _, _metrics = test(_epoch, is_validate=False)

                # torch.save(model, os.path.join("helper_files", "%s-model.pt" % experiment_name))
            elif _epoch % log_interval == 0:
                test(_epoch, is_validate=False)

    else:
        _, _metrics = test(0)

    # with open(os.path.join("result_files", experiment_name + ".json"), "w") as result_file:
    #     json.dump(_metrics, result_file)
    print("METRICS TO DUMP")
    print(_metrics)
# Out:
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 135.14145970344543
# Train Epoch (0) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.694362	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 1.6581413745880127
# Train Epoch (0) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.682474	Batch Accuracy: 62.5%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.229386568069458
# Train Epoch (0) | Batch (2) | [64/540 (12%)]	Batch Loss: 3.347757	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.07480096817016602
# Train Epoch (0) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.818466	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.015957117080688477
# Train Epoch (0) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.650647	Batch Accuracy: 62.5%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.01598525047302246
# Train Epoch (0) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.687310	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.6319229602813721
# Train Epoch (0) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.582865	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.014960765838623047
# Train Epoch (0) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.720021	Batch Accuracy: 75.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.08377385139465332
# Train Epoch (0) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.489484	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.03889608383178711
# Train Epoch (0) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.488528	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.1376338005065918
# Train Epoch (0) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.426971	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.05884194374084473
# Train Epoch (0) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.410589	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.025931358337402344
# Train Epoch (0) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.272608	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.02892279624938965
# Train Epoch (0) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.695330	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.019973278045654297
# Train Epoch (0) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.329449	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.017954111099243164
# Train Epoch (0) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.751423	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.19860601425170898
# Train Epoch (0) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.254186	Batch Accuracy: 89.3%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.2784, Accuracy: 88.89%
# Valid set for malicious : Average Loss: 0.3820, Accuracy: 90.00%
# Valid set for malicious (evasion using natural): Average Loss: 0.3820, Accuracy: 90.00%
# valid set overall: Average Loss: 0.3302, Accuracy: 89.44%
# {'bscn_ratio': 0, 'mal': {'total_loss': 34.378407418727875, 'total_correct': tensor(81), 'total': 90, 'evasion': {'total_loss': 34.378407031297684, 'total_correct': tensor(81), 'total': 90}}, 'bon': {'total_loss': 25.052635669708252, 'total_correct': tensor(80), 'total_evade': None, 'total': 90}}
# Test set for benign : Average Loss: 0.2160, Accuracy: 93.33%
# Test set for malicious : Average Loss: 0.4053, Accuracy: 88.89%
# Test set for malicious (evasion using natural): Average Loss: 0.4053, Accuracy: 88.89%
# test set overall: Average Loss: 0.3107, Accuracy: 91.11%
# {'bscn_ratio': 0, 'mal': {'total_loss': 36.47758996486664, 'total_correct': tensor(80), 'total': 90, 'evasion': {'total_loss': 36.47758996486664, 'total_correct': tensor(80), 'total': 90}}, 'bon': {'total_loss': 19.443252503871918, 'total_correct': tensor(84), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 87.48734450340271
# Train Epoch (1) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.208394	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.11369776725769043
# Train Epoch (1) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.229645	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.052858829498291016
# Train Epoch (1) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.311502	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.11671590805053711
# Train Epoch (1) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.251487	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.06084084510803223
# Train Epoch (1) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.140143	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.03889155387878418
# Train Epoch (1) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.204826	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.15259099006652832
# Train Epoch (1) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.410142	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.028926372528076172
# Train Epoch (1) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.230941	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.03390932083129883
# Train Epoch (1) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.190817	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.06781816482543945
# Train Epoch (1) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.122032	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.3869645595550537
# Train Epoch (1) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.420687	Batch Accuracy: 81.2%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.057848453521728516
# Train Epoch (1) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.145576	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.019947290420532227
# Train Epoch (1) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.124179	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.020943403244018555
# Train Epoch (1) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.575437	Batch Accuracy: 81.2%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.09674239158630371
# Train Epoch (1) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.166074	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.016954421997070312
# Train Epoch (1) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.367188	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.41558408737182617
# Train Epoch (1) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.172137	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.4570, Accuracy: 78.89%
# Valid set for malicious : Average Loss: 0.2340, Accuracy: 95.56%
# Valid set for malicious (evasion using natural): Average Loss: 0.2340, Accuracy: 95.56%
# valid set overall: Average Loss: 0.3455, Accuracy: 87.22%
# {'bscn_ratio': 0, 'mal': {'total_loss': 21.062955155968666, 'total_correct': tensor(86), 'total': 90, 'evasion': {'total_loss': 21.06295555830002, 'total_correct': tensor(86), 'total': 90}}, 'bon': {'total_loss': 41.1265172958374, 'total_correct': tensor(71), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 75.12522864341736
# Train Epoch (2) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.138386	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.0827791690826416
# Train Epoch (2) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.163346	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.023937225341796875
# Train Epoch (2) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.139432	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.021941423416137695
# Train Epoch (2) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.286894	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.024933815002441406
# Train Epoch (2) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.133310	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.019947290420532227
# Train Epoch (2) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.091693	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.02194070816040039
# Train Epoch (2) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.030287	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.01795220375061035
# Train Epoch (2) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.124002	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.01994633674621582
# Train Epoch (2) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.185011	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.021941423416137695
# Train Epoch (2) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.170783	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.01894974708557129
# Train Epoch (2) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.266839	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.01795220375061035
# Train Epoch (2) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.123552	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.020943641662597656
# Train Epoch (2) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.157110	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.018949031829833984
# Train Epoch (2) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.040476	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.030919551849365234
# Train Epoch (2) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.226349	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.017952919006347656
# Train Epoch (2) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.055324	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.01595759391784668
# Train Epoch (2) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.121636	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.4049, Accuracy: 86.67%
# Valid set for malicious : Average Loss: 0.3850, Accuracy: 94.44%
# Valid set for malicious (evasion using natural): Average Loss: 0.3850, Accuracy: 94.44%
# valid set overall: Average Loss: 0.3950, Accuracy: 90.56%
# {'bscn_ratio': 0, 'mal': {'total_loss': 34.64891278743744, 'total_correct': tensor(85), 'total': 90, 'evasion': {'total_loss': 34.64891630411148, 'total_correct': tensor(85), 'total': 90}}, 'bon': {'total_loss': 36.44476518034935, 'total_correct': tensor(78), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 60.370129346847534
# Train Epoch (3) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.059346	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.01795196533203125
# Train Epoch (3) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.048332	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.02094554901123047
# Train Epoch (3) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.099875	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.019945144653320312
# Train Epoch (3) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.067461	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.01894974708557129
# Train Epoch (3) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.042637	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.18151497840881348
# Train Epoch (3) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.042509	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.019945859909057617
# Train Epoch (3) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.046915	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.017951488494873047
# Train Epoch (3) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.026942	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.018949508666992188
# Train Epoch (3) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.006737	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.019947290420532227
# Train Epoch (3) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.067107	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.01994633674621582
# Train Epoch (3) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.291858	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.018952131271362305
# Train Epoch (3) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.065945	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.018947839736938477
# Train Epoch (3) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.240662	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.018947839736938477
# Train Epoch (3) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.455029	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.017952442169189453
# Train Epoch (3) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.141587	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.019946813583374023
# Train Epoch (3) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.088348	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.018949031829833984
# Train Epoch (3) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.044227	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.5984, Accuracy: 83.33%
# Valid set for malicious : Average Loss: 0.4060, Accuracy: 88.89%
# Valid set for malicious (evasion using natural): Average Loss: 0.4060, Accuracy: 88.89%
# valid set overall: Average Loss: 0.5022, Accuracy: 86.11%
# {'bscn_ratio': 0, 'mal': {'total_loss': 36.543888449668884, 'total_correct': tensor(80), 'total': 90, 'evasion': {'total_loss': 36.54388880729675, 'total_correct': tensor(80), 'total': 90}}, 'bon': {'total_loss': 53.85432314872742, 'total_correct': tensor(75), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 62.051372051239014
# Train Epoch (4) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.046297	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.02593064308166504
# Train Epoch (4) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.090334	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.024935483932495117
# Train Epoch (4) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.068409	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.022938251495361328
# Train Epoch (4) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.095122	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.01894855499267578
# Train Epoch (4) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.085887	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.018949508666992188
# Train Epoch (4) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.237244	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.019946813583374023
# Train Epoch (4) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.067025	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.01795220375061035
# Train Epoch (4) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.032905	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.017951250076293945
# Train Epoch (4) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.130699	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.020943403244018555
# Train Epoch (4) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.137465	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.017952442169189453
# Train Epoch (4) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.080051	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.017952442169189453
# Train Epoch (4) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.033225	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.017951488494873047
# Train Epoch (4) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.055221	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.019948720932006836
# Train Epoch (4) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.011583	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.0388951301574707
# Train Epoch (4) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.265603	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.022939205169677734
# Train Epoch (4) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.184197	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.02293872833251953
# Train Epoch (4) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.009975	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.6391, Accuracy: 88.89%
# Valid set for malicious : Average Loss: 0.8007, Accuracy: 91.11%
# Valid set for malicious (evasion using natural): Average Loss: 0.8007, Accuracy: 91.11%
# valid set overall: Average Loss: 0.7199, Accuracy: 90.00%
# {'bscn_ratio': 0, 'mal': {'total_loss': 72.06602372229099, 'total_correct': tensor(82), 'total': 90, 'evasion': {'total_loss': 72.06602551043034, 'total_correct': tensor(82), 'total': 90}}, 'bon': {'total_loss': 57.52172839641571, 'total_correct': tensor(80), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 61.841363191604614
# Train Epoch (5) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.124497	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.020943880081176758
# Train Epoch (5) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.016321	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.01994633674621582
# Train Epoch (5) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.034689	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.017951488494873047
# Train Epoch (5) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.068773	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.020943880081176758
# Train Epoch (5) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.096974	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.02293992042541504
# Train Epoch (5) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.016179	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.021940231323242188
# Train Epoch (5) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.025870	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.018949270248413086
# Train Epoch (5) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.036247	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.02294158935546875
# Train Epoch (5) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.017420	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.018949031829833984
# Train Epoch (5) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.106309	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.020943403244018555
# Train Epoch (5) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.181944	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.018950223922729492
# Train Epoch (5) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.155708	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.021968603134155273
# Train Epoch (5) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.229058	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.01992011070251465
# Train Epoch (5) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.024583	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.019948720932006836
# Train Epoch (5) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.039574	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.018950223922729492
# Train Epoch (5) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.036702	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.030917644500732422
# Train Epoch (5) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.050011	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.4011, Accuracy: 87.78%
# Valid set for malicious : Average Loss: 0.8178, Accuracy: 88.89%
# Valid set for malicious (evasion using natural): Average Loss: 0.8178, Accuracy: 88.89%
# valid set overall: Average Loss: 0.6094, Accuracy: 88.33%
# {'bscn_ratio': 0, 'mal': {'total_loss': 73.60197466611862, 'total_correct': tensor(80), 'total': 90, 'evasion': {'total_loss': 73.60197401046753, 'total_correct': tensor(80), 'total': 90}}, 'bon': {'total_loss': 36.095426892861724, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 61.92733979225159
# Train Epoch (6) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.008242	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.02293872833251953
# Train Epoch (6) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.075426	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.02194070816040039
# Train Epoch (6) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.082958	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.018949508666992188
# Train Epoch (6) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.011509	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.015956878662109375
# Train Epoch (6) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.047141	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.014960289001464844
# Train Epoch (6) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.001720	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.01695394515991211
# Train Epoch (6) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.051258	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.014960050582885742
# Train Epoch (6) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.015770	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.01595020294189453
# Train Epoch (6) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.046720	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.013964414596557617
# Train Epoch (6) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.206298	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.21243071556091309
# Train Epoch (6) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.029401	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.01795196533203125
# Train Epoch (6) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.032947	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.01795220375061035
# Train Epoch (6) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.188691	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.01795220375061035
# Train Epoch (6) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.068811	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.016954660415649414
# Train Epoch (6) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.022691	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.01695394515991211
# Train Epoch (6) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.003178	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.01795220375061035
# Train Epoch (6) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.020202	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 1.7591, Accuracy: 77.78%
# Valid set for malicious : Average Loss: 0.7292, Accuracy: 93.33%
# Valid set for malicious (evasion using natural): Average Loss: 0.7292, Accuracy: 93.33%
# valid set overall: Average Loss: 1.2442, Accuracy: 85.56%
# {'bscn_ratio': 0, 'mal': {'total_loss': 65.62849223613739, 'total_correct': tensor(84), 'total': 90, 'evasion': {'total_loss': 65.62849497795105, 'total_correct': tensor(84), 'total': 90}}, 'bon': {'total_loss': 158.32279586791992, 'total_correct': tensor(70), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 63.554365396499634
# Train Epoch (7) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.055499	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.021943092346191406
# Train Epoch (7) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.053997	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.022940874099731445
# Train Epoch (7) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.107331	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.015956878662109375
# Train Epoch (7) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.057511	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.017952919006347656
# Train Epoch (7) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.061251	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.015957117080688477
# Train Epoch (7) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.022031	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.016954660415649414
# Train Epoch (7) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.061328	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.017951488494873047
# Train Epoch (7) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.019942	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.01795220375061035
# Train Epoch (7) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.031905	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.029919147491455078
# Train Epoch (7) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.213382	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.01695537567138672
# Train Epoch (7) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.197419	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.020944833755493164
# Train Epoch (7) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.018929	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.016954421997070312
# Train Epoch (7) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.069608	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.018950223922729492
# Train Epoch (7) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.036593	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.017952680587768555
# Train Epoch (7) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.029507	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.016952991485595703
# Train Epoch (7) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.061317	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.015958070755004883
# Train Epoch (7) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.034755	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 1.0073, Accuracy: 82.22%
# Valid set for malicious : Average Loss: 0.3457, Accuracy: 93.33%
# Valid set for malicious (evasion using natural): Average Loss: 0.3457, Accuracy: 93.33%
# valid set overall: Average Loss: 0.6765, Accuracy: 87.78%
# {'bscn_ratio': 0, 'mal': {'total_loss': 31.10952091217041, 'total_correct': tensor(84), 'total': 90, 'evasion': {'total_loss': 31.10952179133892, 'total_correct': tensor(84), 'total': 90}}, 'bon': {'total_loss': 90.65628480911255, 'total_correct': tensor(74), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 61.69482731819153
# Train Epoch (8) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.020757	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.03191566467285156
# Train Epoch (8) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.034827	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.030915498733520508
# Train Epoch (8) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.067558	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.0219419002532959
# Train Epoch (8) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.001810	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.03091740608215332
# Train Epoch (8) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.033411	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.020944595336914062
# Train Epoch (8) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.017797	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.018947362899780273
# Train Epoch (8) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.003286	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.022939205169677734
# Train Epoch (8) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.037640	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.01894974708557129
# Train Epoch (8) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.078020	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.01994609832763672
# Train Epoch (8) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.002187	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.020943641662597656
# Train Epoch (8) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.060969	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.021942138671875
# Train Epoch (8) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.030771	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.019948720932006836
# Train Epoch (8) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.044756	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.019946575164794922
# Train Epoch (8) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.006563	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.022938251495361328
# Train Epoch (8) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.042644	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.02293872833251953
# Train Epoch (8) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.196051	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.019947290420532227
# Train Epoch (8) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.031771	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 2.2792, Accuracy: 84.44%
# Valid set for malicious : Average Loss: 1.0759, Accuracy: 93.33%
# Valid set for malicious (evasion using natural): Average Loss: 1.0759, Accuracy: 93.33%
# valid set overall: Average Loss: 1.6776, Accuracy: 88.89%
# {'bscn_ratio': 0, 'mal': {'total_loss': 96.83462870121002, 'total_correct': tensor(84), 'total': 90, 'evasion': {'total_loss': 96.83462618291378, 'total_correct': tensor(84), 'total': 90}}, 'bon': {'total_loss': 205.13144776201807, 'total_correct': tensor(76), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000001D2F5100978> <datasets.datasets.PortableExecutableDataset object at 0x000001D2EDD10080>
# This is bacth_idx 0
# Time Taken: 60.93122053146362
# Train Epoch (9) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.000051	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# Time Taken: 0.01795053482055664
# Train Epoch (9) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.045470	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# Time Taken: 0.01795220375061035
# Train Epoch (9) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.028661	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# Time Taken: 0.01894998550415039
# Train Epoch (9) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.046306	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 4
# Time Taken: 0.017951488494873047
# Train Epoch (9) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.059858	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# Time Taken: 0.015957355499267578
# Train Epoch (9) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.160538	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 6
# Time Taken: 0.01795196533203125
# Train Epoch (9) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.020723	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# Time Taken: 0.02094411849975586
# Train Epoch (9) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.013613	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# Time Taken: 0.01795220375061035
# Train Epoch (9) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.032414	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# Time Taken: 0.01795220375061035
# Train Epoch (9) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.046353	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# Time Taken: 0.03490614891052246
# Train Epoch (9) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.189713	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 11
# Time Taken: 0.016954898834228516
# Train Epoch (9) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.014646	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# Time Taken: 0.016956806182861328
# Train Epoch (9) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.042952	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 13
# Time Taken: 0.018947124481201172
# Train Epoch (9) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.003031	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# Time Taken: 0.01894998550415039
# Train Epoch (9) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.037819	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# Time Taken: 0.016954660415649414
# Train Epoch (9) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.052262	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 16
# Time Taken: 0.016954660415649414
# Train Epoch (9) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.006610	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.9672, Accuracy: 87.78%
# Valid set for malicious : Average Loss: 1.7044, Accuracy: 91.11%
# Valid set for malicious (evasion using natural): Average Loss: 1.7044, Accuracy: 91.11%
# valid set overall: Average Loss: 1.3358, Accuracy: 89.44%
# {'bscn_ratio': 0, 'mal': {'total_loss': 153.39623319357634, 'total_correct': tensor(82), 'total': 90, 'evasion': {'total_loss': 153.39624268561602, 'total_correct': tensor(82), 'total': 90}}, 'bon': {'total_loss': 87.0498640537262, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}
# METRICS TO DUMP
# {'bscn_ratio': 0, 'mal': {'total_loss': 36.47758996486664, 'total_correct': tensor(80), 'total': 90, 'evasion': {'total_loss': 36.47758996486664, 'total_correct': tensor(80), 'total': 90}}, 'bon': {'total_loss': 19.443252503871918, 'total_correct': tensor(84), 'total_evade': None, 'total': 90}}

# %%
type(_metrics)
# Out:
# dict

# %%
_metrics
# Out:
# {'bscn_ratio': 0,
#  'mal': {'total_loss': 36.47758996486664,
#   'total_correct': tensor(80),
#   'total': 90,
#   'evasion': {'total_loss': 36.47758996486664,
#    'total_correct': tensor(80),
#    'total': 90}},
#  'bon': {'total_loss': 19.443252503871918,
#   'total_correct': tensor(84),
#   'total_evade': None,
#   'total': 90}}

# %%
_metrics['mal']['total']
# Out:
# 90

# %%
def confMat(_metrics):
    total_mal = _metrics['mal']['total']
    total_mal_correct = _metrics['mal']['total_correct']
    total_mal_wrong = total_mal - total_mal_correct
    
    total_ben = _metrics['bon']['total']
    total_ben_correct = _metrics['bon']['total_correct']
    total_ben_wrong = total_ben - total_ben_correct
    
    true_list = []
    for i in range(total_mal):
        true_list.append(1)
    for i in range(total_ben):
        true_list.append(0)
        
    pred_list = []
    for i in range(total_mal_correct):
        pred_list.append(1)
    for i in range(total_mal_wrong):
        pred_list.append(0)
    for i in range(total_ben_correct):
        pred_list.append(0)
    for i in range(total_ben_wrong):
        pred_list.append(1)
    return true_list,pred_list

# %%
TrueList,PredList = confMat(_metrics)

# %%
np.unique(np.array(TrueList),return_counts=True)
# Out:
# (array([0, 1]), array([90, 90], dtype=int64))

# %%
np.unique(np.array(PredList),return_counts=True)
# Out:
# (array([0, 1]), array([94, 86], dtype=int64))

# %%
from sklearn import metrics

# %%
print(metrics.confusion_matrix(TrueList,PredList))
# Out:
# [[84  6]
#  [10 80]]

# %%
print(metrics.classification_report(TrueList,PredList))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        90
#            1       0.93      0.89      0.91        90
#
#     accuracy                           0.91       180
#    macro avg       0.91      0.91      0.91       180
# weighted avg       0.91      0.91      0.91       180
