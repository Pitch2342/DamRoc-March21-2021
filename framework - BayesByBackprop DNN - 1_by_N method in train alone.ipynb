# %%
import os
import torch
import random
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from utils.utils import load_parameters, stack_tensors
from datasets.datasets import load_data
from inner_maximizers.inner_maximizers import inner_maximizer
from nets.ff_classifier import build_ff_classifier
import losswise
import time
import json
import numpy as np

# %%
parameters = load_parameters("parameters.ini")
is_cuda = eval(parameters["general"]["is_cuda"])
if is_cuda:
    os.environ["CUDA_VISIBLE_DEVICES"] = parameters["general"]["gpu_device"]

assertion_message = "Set this flag off to train models."
assert eval(parameters['dataset']['generate_feature_vector_files']) is False, assertion_message

log_interval = int(parameters["general"]["log_interval"])
num_epochs = int(parameters["hyperparam"]["ff_num_epochs"])
is_losswise = eval(parameters["general"]["is_losswise"])
is_synthetic_dataset = eval(parameters["general"]["is_synthetic_dataset"])

training_method = parameters["general"]["training_method"]
evasion_method = parameters["general"]["evasion_method"]
experiment_suffix = parameters["general"]["experiment_suffix"]
experiment_name = "[training:%s|evasion:%s]_%s" % (training_method, evasion_method,
                                                   experiment_suffix)

print("Training Method:%s, Evasion Method:%s" % (training_method, evasion_method))

seed_val = int(parameters["general"]["seed"])

random.seed(seed_val)
torch.manual_seed(seed_val)
np.random.seed(seed_val)
# Out:
# Training Method:rfgsm_k, Evasion Method:natural

# %%
evasion_iterations = int(parameters['hyperparam']['evasion_iterations'])

save_every_epoch = eval(parameters['general']['save_every_epoch'])

train_model_from_scratch = eval(parameters['general']['train_model_from_scratch'])
load_model_weights = eval(parameters['general']['load_model_weights'])
model_weights_path = parameters['general']['model_weights_path']

# %%
train_dataloader_dict, valid_dataloader_dict, test_dataloader_dict, num_features = load_data(
    parameters)
# Out:
# Starting data loading
# Creating import to index mapping
# -- accessing file: ./helper_files/N5000/pmal/
# -- accessing file: ./helper_files/N5000/pben/
# Malicious files: 500
# Benign files: 500
# Total number of files: 1000
# 0 Time: 0.0  seconds
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# ...
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# Traceback (most recent call last):
#   File "C:\Users\Pitch\Desktop\Sem8\Frameworks Pitch\March 19 work\datasets\datasets.py", line 72, in create_import_to_index_mapping
#     lib.name.lower() + ':' + e.name for lib in binary.imports for e in lib.entries
# AttributeError: 'NoneType' object has no attribute 'imports'
# -- accessing file: ./helper_files/None.txt
# -- accessing file: ./helper_files/N5000/pmal/
# -- accessing file: ./helper_files/N5000/pben/
# Malware Files: 450
# Benign Files: 450
# Preparing training datasets
# Preparing validation datasets
# Preparing testing datasets
# FAL
# ./helper_files/N5000/pmal/Pickle_malware198.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign479.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware5.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign204.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware5.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign479.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware198.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign204.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware247.pt
# FV
# tensor([0., 0., 1.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign228.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pmal/Pickle_malware247.pt
# FV
# tensor([0., 0., 1.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign479.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# FAL
# ./helper_files/N5000/pben/Pickle_benign479.pt
# FV
# tensor([0., 0., 0.,  ..., 0., 0., 0.])
# This is trainMalicious ['./helper_files/N5000/pmal/Pickle_malware0.pt', './helper_files/N5000/pmal/Pickle_malware1.pt', './helper_files/N5000/pmal/Pickle_malware10.pt', './helper_files/N5000/pmal/Pickle_malware100.pt', './helper_files/N5000/pmal/Pickle_malware101.pt', './helper_files/N5000/pmal/Pickle_malware102.pt', './helper_files/N5000/pmal/Pickle_malware103.pt', './helper_files/N5000/pmal/Pickle_malware104.pt', './helper_files/N5000/pmal/Pickle_malware105.pt', './helper_files/N5000/pmal/Pickle_malware106.pt', './helper_files/N5000/pmal/Pickle_malware107.pt', './helper_files/N5000/pmal/Pickle_malware108.pt', './helper_files/N5000/pmal/Pickle_malware109.pt', './helper_files/N5000/pmal/Pickle_malware11.pt', './helper_files/N5000/pmal/Pickle_malware110.pt', './helper_files/N5000/pmal/Pickle_malware111.pt', './helper_files/N5000/pmal/Pickle_malware112.pt', './helper_files/N5000/pmal/Pickle_malware113.pt', './helper_files/N5000/pmal/Pickle_malware114.pt', './helper_files/N5000/pmal/Pickle_malware115.pt', './helper_files/N5000/pmal/Pickle_malware116.pt', './helper_files/N5000/pmal/Pickle_malware117.pt', './helper_files/N5000/pmal/Pickle_malware118.pt', './helper_files/N5000/pmal/Pickle_malware119.pt', './helper_files/N5000/pmal/Pickle_malware12.pt', './helper_files/N5000/pmal/Pickle_malware120.pt', './helper_files/N5000/pmal/Pickle_malware121.pt', './helper_files/N5000/pmal/Pickle_malware122.pt', './helper_files/N5000/pmal/Pickle_malware123.pt', './helper_files/N5000/pmal/Pickle_malware124.pt', './helper_files/N5000/pmal/Pickle_malware125.pt', './helper_files/N5000/pmal/Pickle_malware126.pt', './helper_files/N5000/pmal/Pickle_malware127.pt', './helper_files/N5000/pmal/Pickle_malware128.pt', './helper_files/N5000/pmal/Pickle_malware129.pt', './helper_files/N5000/pmal/Pickle_malware13.pt', './helper_files/N5000/pmal/Pickle_malware130.pt', './helper_files/N5000/pmal/Pickle_malware131.pt', './helper_files/N5000/pmal/Pickle_malware132.pt', './helper_files/N5000/pmal/Pickle_malware133.pt', './helper_files/N5000/pmal/Pickle_malware134.pt', './helper_files/N5000/pmal/Pickle_malware135.pt', './helper_files/N5000/pmal/Pickle_malware136.pt', './helper_files/N5000/pmal/Pickle_malware137.pt', './helper_files/N5000/pmal/Pickle_malware138.pt', './helper_files/N5000/pmal/Pickle_malware139.pt', './helper_files/N5000/pmal/Pickle_malware14.pt', './helper_files/N5000/pmal/Pickle_malware140.pt', './helper_files/N5000/pmal/Pickle_malware141.pt', './helper_files/N5000/pmal/Pickle_malware142.pt', './helper_files/N5000/pmal/Pickle_malware143.pt', './helper_files/N5000/pmal/Pickle_malware144.pt', './helper_files/N5000/pmal/Pickle_malware145.pt', './helper_files/N5000/pmal/Pickle_malware146.pt', './helper_files/N5000/pmal/Pickle_malware147.pt', './helper_files/N5000/pmal/Pickle_malware148.pt', './helper_files/N5000/pmal/Pickle_malware149.pt', './helper_files/N5000/pmal/Pickle_malware15.pt', './helper_files/N5000/pmal/Pickle_malware150.pt', './helper_files/N5000/pmal/Pickle_malware151.pt', './helper_files/N5000/pmal/Pickle_malware152.pt', './helper_files/N5000/pmal/Pickle_malware153.pt', './helper_files/N5000/pmal/Pickle_malware154.pt', './helper_files/N5000/pmal/Pickle_malware155.pt', './helper_files/N5000/pmal/Pickle_malware156.pt', './helper_files/N5000/pmal/Pickle_malware157.pt', './helper_files/N5000/pmal/Pickle_malware158.pt', './helper_files/N5000/pmal/Pickle_malware159.pt', './helper_files/N5000/pmal/Pickle_malware16.pt', './helper_files/N5000/pmal/Pickle_malware160.pt', './helper_files/N5000/pmal/Pickle_malware161.pt', './helper_files/N5000/pmal/Pickle_malware162.pt', './helper_files/N5000/pmal/Pickle_malware163.pt', './helper_files/N5000/pmal/Pickle_malware164.pt', './helper_files/N5000/pmal/Pickle_malware165.pt', './helper_files/N5000/pmal/Pickle_malware166.pt', './helper_files/N5000/pmal/Pickle_malware167.pt', './helper_files/N5000/pmal/Pickle_malware168.pt', './helper_files/N5000/pmal/Pickle_malware169.pt', './helper_files/N5000/pmal/Pickle_mal ...

# %%
num_samples = len(train_dataloader_dict["malicious"].dataset)

# %%
model = build_ff_classifier(
        input_size=num_features,
        hidden_1_size=int(parameters["hyperparam"]["ff_h1"]),
        hidden_2_size=int(parameters["hyperparam"]["ff_h2"]),
        hidden_3_size=int(parameters["hyperparam"]["ff_h3"]))
model
# Out:
# Sequential(
#   (0): Linear(in_features=2948, out_features=300, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=300, out_features=300, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=300, out_features=300, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=300, out_features=2, bias=True)
#   (7): LogSoftmax(dim=1)
# )

# %%
import torch.nn.functional as F

def get_beta(batch_idx, m, beta_type, epoch, num_epochs):
    if beta_type == "Blundell":
        beta = 2 ** (m - (batch_idx + 1)) / (2 ** m - 1)
    elif beta_type == "Soenderby":
        beta = min(epoch / (num_epochs // 4), 1)
    elif beta_type == "Standard":
        beta = 1 / m
    else:
        beta = 0
    return beta

def elbo(out, y, kl_sum, beta):
    ce_loss = F.cross_entropy(out, y)
    return ce_loss + beta * kl_sum

# %%
loss_fct = nn.NLLLoss(reduce=False)
optimizer = optim.Adam(model.parameters(), lr=float(parameters["hyperparam"]["ff_learning_rate"]))
optimizer
# Out:
# C:\ProgramData\Anaconda3\envs\nn_mal_2\lib\site-packages\torch\nn\_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.01
#     weight_decay: 0
# )

# %%
NumCount = 0
Visited = []

# %%
def train(epoch):
    model.train()
    total_correct = 0.
    total_loss = 0.
    total = 0.

    current_time = time.time()

    if is_synthetic_dataset:
        # since generation of synthetic data set is random, we'd like them to be the same over epochs
        torch.manual_seed(seed_val)
        random.seed(seed_val)
    print("dataloaderr",train_dataloader_dict["benign"].dataset, train_dataloader_dict["malicious"].dataset)
    for batch_idx, ((bon_x, bon_y), (mal_x, mal_y)) in enumerate(
            zip(train_dataloader_dict["benign"], train_dataloader_dict["malicious"])):
        # Check for adversarial learning
        print("This is bacth_idx",batch_idx)
#         print(bon_x)
#         print(bon_y)
#         print(mal_x)
#         print(mal_y)
#         mal_x1 = inner_maximizer(
#             mal_x, mal_y, model, loss_fct, iterations=evasion_iterations, method=training_method)
#         print("THis is mal_X",mal_x1)
        # stack input
#         if is_cuda:
#             x = Variable(stack_tensors(bon_x, mal_x, mal_x1).cuda())
#             y = Variable(stack_tensors(bon_y, mal_y, mal_y).cuda())
#         else:
#             x = Variable(stack_tensors(bon_x, mal_x, mal_x1))
#             y = Variable(stack_tensors(bon_y, mal_y, mal_y))
        x = Variable(stack_tensors(bon_x, mal_x))
        y = Variable(stack_tensors(bon_y, mal_y))
#         print("STACKED")
#         print(x)
#         print(y)
#         print("This is Train Forward Pass",x, y, model )
        
        # forward pass
#         print("FORWARD X")
#         print(x)
        y_model = model(x)
#         print("YMODEL")
#         print(y_model)

        # backward pass
    # batch_idx, m, beta_type, epoch, num_epochs
        optimizer.zero_grad()
        y_model = model(x)
        kl = loss_fct(y_model, y).mean()
        print("BETA VALS")
        print(batch_idx,
                             (train_dataloader_dict["benign"].dataset.__len__() 
                                    + train_dataloader_dict["malicious"].dataset.__len__()),
                            "Standard",
                            epoch,
                            num_epochs)
        loss = elbo(y_model, y, kl, 
                    get_beta(batch_idx,
                             (train_dataloader_dict["benign"].dataset.__len__() 
                                    + train_dataloader_dict["malicious"].dataset.__len__()),
                            "Standard",
                            epoch,
                            num_epochs))
        loss.backward()
        optimizer.step()

        # predict pass
        _, predicted = torch.topk(y_model, k=1)
        correct = predicted.data.eq(y.data.view_as(predicted.data)).cpu().sum()

        # metrics
#         print("LOSS LINE 148")
#         print(len(y))
#         print(y)
#         print(total_loss)
#         print(loss.data)
#         print(loss.data.item())
        # total_loss += loss.data[0] * len(y)
        total_loss += loss.data.item() * len(y)

        total_correct += correct
        total += len(y)

        

        if 15%5 == 0:

            print("Time Taken:", time.time() - current_time)
            current_time = time.time()

            print(
                "Train Epoch ({}) | Batch ({}) | [{}/{} ({:.0f}%)]\tBatch Loss: {:.6f}\tBatch Accuracy: {:.1f}%\t BSCN: {:.12f}".
                # format(epoch, batch_idx, batch_idx * len(x),
                #        len(train_dataloader_dict["malicious"].dataset) +
                #        len(train_dataloader_dict["benign"].dataset),
                #        100. * batch_idx / len(train_dataloader_dict["benign"]), loss.data[0],
                #        100. * correct / len(y), bscn.ratio()))
                format(epoch, batch_idx, batch_idx * len(x),
                       len(train_dataloader_dict["malicious"].dataset) +
                       len(train_dataloader_dict["benign"].dataset),
                       100. * batch_idx / len(train_dataloader_dict["benign"]), loss.data.item(),
                       100. * correct / len(y), 1))

# %%
def check_one_category(category="benign", is_validate=False, is_evade=False,
                       evade_method='natural'):
    """
    test the model in terms of loss and accuracy on category, this function also allows to perform perturbation
    with respect to loss to evade
    :param category: benign or malicious dataset
    :param is_validate: validation or testing dataset
    :param is_evade: to perform evasion or not
    :param evade_method: evasion method (we can use on of the inner maximier methods), it is only relevant if is_evade
      is True
    :return:
    """
    model.eval()
    total_loss = 0
    total_correct = 0
    total = 0
    evasion_mode = ""

    if is_synthetic_dataset:
        # since generation of synthetic data set is random, we'd like them to be the same over epochs
        torch.manual_seed(seed_val)
        random.seed(seed_val)

    if is_validate:
        dataloader = valid_dataloader_dict[category]
    else:
        dataloader = test_dataloader_dict[category]

    for batch_idx, (x, y) in enumerate(dataloader):
        #
        if is_evade:
            x = inner_maximizer(
                x, y, model, loss_fct, iterations=evasion_iterations, method='natural')
            evasion_mode = "(evasion using %s)" % evade_method
        # stack input
        if is_cuda:
            x = Variable(x.cuda())
            y = Variable(y.cuda())
        else:
            x = Variable(x)
            y = Variable(y)
#         print("Check one CategoryForward Pass", x, y, model)
        # forward pass
        y_model = model(x)

        # loss pass
        loss = loss_fct(y_model, y).mean()

        # predict pass
        _, predicted = torch.topk(y_model, k=1)
        correct = predicted.data.eq(y.data.view_as(predicted.data)).cpu().sum()

        # metrics
        # total_loss += loss.data[0] * len(y)
        total_loss += loss.data.item() * len(y)
        total_correct += correct
        total += len(y)

    print("{} set for {} {}: Average Loss: {:.4f}, Accuracy: {:.2f}%".format(
        "Valid" if is_validate else "Test", category, evasion_mode, total_loss / total,
        total_correct * 100. / total))

    return total_loss, total_correct, total

# %%
def test(epoch, is_validate=False):
    """
    Function to be used for both testing and validation
    :param epoch: current epoch
    :param is_validate: is the testing done on the validation dataset
    :return: average total loss, dictionary of the metrics for both bon and mal samples
    """
    # test for accuracy and loss
    bon_total_loss, bon_total_correct, bon_total = check_one_category(
        category="benign", is_evade=False, is_validate=is_validate)
    mal_total_loss, mal_total_correct, mal_total = check_one_category(
        category="malicious", is_evade=False, is_validate=is_validate)

    # test for evasion on malicious sample
    evade_mal_total_loss, evade_mal_total_correct, evade_mal_total = check_one_category(
        category="malicious", is_evade=True, evade_method=evasion_method, is_validate=is_validate)

    total_loss = bon_total_loss + mal_total_loss
    total_correct = bon_total_correct + mal_total_correct
    total = bon_total + mal_total

    dataset_type = "valid" if is_validate else "test"

    print("{} set overall: Average Loss: {:.4f}, Accuracy: {:.2f}%".format(
        dataset_type, total_loss / total, total_correct * 100. / total))

    if is_losswise:
        graph_accuracy.append(
            epoch, {
                "%s_accuracy_%s" % (dataset_type, experiment_name): 100. * total_correct / total
            })
        graph_loss.append(epoch, {
            "%s_loss_%s" % (dataset_type, experiment_name): total_loss / total
        })
        graph_evasion.append(
            epoch, {
                "%s_evasion_%s" % (dataset_type, experiment_name):
                100 * (evade_mal_total - evade_mal_total_correct) / evade_mal_total
            })

    metrics = {
        "bscn_ratio": 0,
        "mal": {
            "total_loss": mal_total_loss,
            "total_correct": mal_total_correct,
            "total": mal_total,
            "evasion": {
                "total_loss": evade_mal_total_loss,
                "total_correct": evade_mal_total_correct,
                "total": evade_mal_total
            }
        },
        "bon": {
            "total_loss": bon_total_loss,
            "total_correct": bon_total_correct,
            "total_evade": None,
            "total": bon_total
        }
    }
    print(metrics)

    return (bon_total_loss + max(mal_total_loss, evade_mal_total_loss)) / total, metrics

# %%
_metrics = 0
if __name__ == "__main__":

    if not os.path.exists("result_files"):
        os.mkdir("result_files")

    _metrics = None
    session = None
    if train_model_from_scratch:
        best_valid_loss = float("inf")
        for _epoch in range(num_epochs):
            # train
            train(_epoch)

            # validate
            valid_loss, _ = test(_epoch, is_validate=True)

            # keep the best parameters w.r.t validation and check the test set
            if best_valid_loss > valid_loss:
                best_valid_loss = valid_loss
                _, _metrics = test(_epoch, is_validate=False)

                # torch.save(model, os.path.join("helper_files", "%s-model.pt" % experiment_name))
            elif _epoch % log_interval == 0:
                test(_epoch, is_validate=False)

    else:
        _, _metrics = test(0)

    # with open(os.path.join("result_files", experiment_name + ".json"), "w") as result_file:
    #     json.dump(_metrics, result_file)
    print("METRICS TO DUMP")
    print(_metrics)
# Out:
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 0 10
# Time Taken: 202.74137616157532
# Train Epoch (0) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.695648	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 0 10
# Time Taken: 0.41788363456726074
# Train Epoch (0) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.683738	Batch Accuracy: 62.5%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 0 10
# Time Taken: 0.29421329498291016
# Train Epoch (0) | Batch (2) | [64/540 (12%)]	Batch Loss: 3.353946	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 0 10
# Time Taken: 0.26628804206848145
# Train Epoch (0) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.819983	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 0 10
# Time Taken: 0.37400054931640625
# Train Epoch (0) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.651853	Batch Accuracy: 62.5%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 0 10
# Time Taken: 0.32213783264160156
# Train Epoch (0) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.688583	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 0 10
# Time Taken: 0.2682828903198242
# Train Epoch (0) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.583941	Batch Accuracy: 50.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 0 10
# Time Taken: 0.2672858238220215
# Train Epoch (0) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.721442	Batch Accuracy: 75.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 0 10
# Time Taken: 0.11170005798339844
# Train Epoch (0) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.490376	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 0 10
# Time Taken: 0.27526402473449707
# Train Epoch (0) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.489407	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 0 10
# Time Taken: 0.4747304916381836
# Train Epoch (0) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.427826	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 0 10
# Time Taken: 0.34707212448120117
# Train Epoch (0) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.411441	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 0 10
# Time Taken: 0.03490567207336426
# Train Epoch (0) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.272955	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 0 10
# Time Taken: 0.021941184997558594
# Train Epoch (0) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.696166	Batch Accuracy: 84.4%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 0 10
# Time Taken: 0.021941184997558594
# Train Epoch (0) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.329958	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 0 10
# Time Taken: 0.027925968170166016
# Train Epoch (0) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.751239	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 0 10
# Time Taken: 0.6311559677124023
# Train Epoch (0) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.255667	Batch Accuracy: 89.3%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.2777, Accuracy: 88.89%
# Valid set for malicious : Average Loss: 0.3821, Accuracy: 90.00%
# Valid set for malicious (evasion using natural): Average Loss: 0.3821, Accuracy: 90.00%
# valid set overall: Average Loss: 0.3299, Accuracy: 89.44%
# {'bscn_ratio': 0, 'mal': {'total_loss': 34.3903883099556, 'total_correct': tensor(81), 'total': 90, 'evasion': {'total_loss': 34.39038798213005, 'total_correct': tensor(81), 'total': 90}}, 'bon': {'total_loss': 24.99137157201767, 'total_correct': tensor(80), 'total_evade': None, 'total': 90}}
# Test set for benign : Average Loss: 0.2153, Accuracy: 93.33%
# Test set for malicious : Average Loss: 0.4060, Accuracy: 88.89%
# Test set for malicious (evasion using natural): Average Loss: 0.4060, Accuracy: 88.89%
# test set overall: Average Loss: 0.3106, Accuracy: 91.11%
# {'bscn_ratio': 0, 'mal': {'total_loss': 36.540499806404114, 'total_correct': tensor(80), 'total': 90, 'evasion': {'total_loss': 36.540499806404114, 'total_correct': tensor(80), 'total': 90}}, 'bon': {'total_loss': 19.373232007026672, 'total_correct': tensor(84), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 1 10
# Time Taken: 78.22553777694702
# Train Epoch (1) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.208966	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 1 10
# Time Taken: 0.10471987724304199
# Train Epoch (1) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.231023	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 1 10
# Time Taken: 0.04487919807434082
# Train Epoch (1) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.308705	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 1 10
# Time Taken: 0.02593064308166504
# Train Epoch (1) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.252679	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 1 10
# Time Taken: 0.10671496391296387
# Train Epoch (1) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.139330	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 1 10
# Time Taken: 0.0219423770904541
# Train Epoch (1) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.182403	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 1 10
# Time Taken: 0.04587721824645996
# Train Epoch (1) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.388309	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 1 10
# Time Taken: 0.020944833755493164
# Train Epoch (1) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.223954	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 1 10
# Time Taken: 0.1047205924987793
# Train Epoch (1) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.179543	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 1 10
# Time Taken: 0.04488039016723633
# Train Epoch (1) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.117039	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 1 10
# Time Taken: 0.0747995376586914
# Train Epoch (1) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.417271	Batch Accuracy: 81.2%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 1 10
# Time Taken: 0.3470723628997803
# Train Epoch (1) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.144343	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 1 10
# Time Taken: 0.05585050582885742
# Train Epoch (1) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.118559	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 1 10
# Time Taken: 0.0219419002532959
# Train Epoch (1) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.611784	Batch Accuracy: 81.2%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 1 10
# Time Taken: 0.09973335266113281
# Train Epoch (1) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.156490	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 1 10
# Time Taken: 0.022938966751098633
# Train Epoch (1) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.397907	Batch Accuracy: 78.1%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 1 10
# Time Taken: 0.5126302242279053
# Train Epoch (1) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.198449	Batch Accuracy: 92.9%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.4203, Accuracy: 81.11%
# Valid set for malicious : Average Loss: 0.2562, Accuracy: 92.22%
# Valid set for malicious (evasion using natural): Average Loss: 0.2562, Accuracy: 92.22%
# valid set overall: Average Loss: 0.3382, Accuracy: 86.67%
# {'bscn_ratio': 0, 'mal': {'total_loss': 23.056569576263428, 'total_correct': tensor(83), 'total': 90, 'evasion': {'total_loss': 23.05656948685646, 'total_correct': tensor(83), 'total': 90}}, 'bon': {'total_loss': 37.826518297195435, 'total_correct': tensor(73), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 2 10
# Time Taken: 58.22188591957092
# Train Epoch (2) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.152701	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 2 10
# Time Taken: 0.08577108383178711
# Train Epoch (2) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.161877	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 2 10
# Time Taken: 0.046874284744262695
# Train Epoch (2) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.141495	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 2 10
# Time Taken: 0.02094411849975586
# Train Epoch (2) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.298589	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 2 10
# Time Taken: 0.019948720932006836
# Train Epoch (2) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.118517	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 2 10
# Time Taken: 0.021941184997558594
# Train Epoch (2) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.103399	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 2 10
# Time Taken: 0.02293848991394043
# Train Epoch (2) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.037234	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 2 10
# Time Taken: 0.02194070816040039
# Train Epoch (2) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.115213	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 2 10
# Time Taken: 0.021941423416137695
# Train Epoch (2) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.247899	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 2 10
# Time Taken: 0.02094435691833496
# Train Epoch (2) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.135497	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 2 10
# Time Taken: 0.10870933532714844
# Train Epoch (2) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.276392	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 2 10
# Time Taken: 0.026928424835205078
# Train Epoch (2) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.110250	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 2 10
# Time Taken: 0.029920578002929688
# Train Epoch (2) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.180314	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 2 10
# Time Taken: 0.022939205169677734
# Train Epoch (2) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.043024	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 2 10
# Time Taken: 0.021942138671875
# Train Epoch (2) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.233760	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 2 10
# Time Taken: 0.02094411849975586
# Train Epoch (2) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.060981	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 2 10
# Time Taken: 0.022937774658203125
# Train Epoch (2) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.133754	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.3423, Accuracy: 87.78%
# Valid set for malicious : Average Loss: 0.3914, Accuracy: 93.33%
# Valid set for malicious (evasion using natural): Average Loss: 0.3914, Accuracy: 93.33%
# valid set overall: Average Loss: 0.3668, Accuracy: 90.56%
# {'bscn_ratio': 0, 'mal': {'total_loss': 35.22726094722748, 'total_correct': tensor(84), 'total': 90, 'evasion': {'total_loss': 35.22726109623909, 'total_correct': tensor(84), 'total': 90}}, 'bon': {'total_loss': 30.803707361221313, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 3 10
# Time Taken: 58.30704641342163
# Train Epoch (3) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.071389	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 3 10
# Time Taken: 0.028922557830810547
# Train Epoch (3) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.047433	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 3 10
# Time Taken: 0.026927471160888672
# Train Epoch (3) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.098068	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 3 10
# Time Taken: 0.02692890167236328
# Train Epoch (3) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.068475	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 3 10
# Time Taken: 0.020943641662597656
# Train Epoch (3) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.034973	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 3 10
# Time Taken: 0.02094268798828125
# Train Epoch (3) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.062605	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 3 10
# Time Taken: 0.024933815002441406
# Train Epoch (3) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.061679	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 3 10
# Time Taken: 0.02393364906311035
# Train Epoch (3) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.039769	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 3 10
# Time Taken: 0.021941423416137695
# Train Epoch (3) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.016324	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 3 10
# Time Taken: 0.019944190979003906
# Train Epoch (3) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.052995	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 3 10
# Time Taken: 0.024934053421020508
# Train Epoch (3) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.231344	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 3 10
# Time Taken: 0.02493429183959961
# Train Epoch (3) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.063239	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 3 10
# Time Taken: 0.026927709579467773
# Train Epoch (3) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.126120	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 3 10
# Time Taken: 0.027925491333007812
# Train Epoch (3) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.393463	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 3 10
# Time Taken: 0.02393794059753418
# Train Epoch (3) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.085738	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 3 10
# Time Taken: 0.023936748504638672
# Train Epoch (3) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.153438	Batch Accuracy: 87.5%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 3 10
# Time Taken: 0.023935556411743164
# Train Epoch (3) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.026596	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.6843, Accuracy: 87.78%
# Valid set for malicious : Average Loss: 0.6518, Accuracy: 90.00%
# Valid set for malicious (evasion using natural): Average Loss: 0.6518, Accuracy: 90.00%
# valid set overall: Average Loss: 0.6680, Accuracy: 88.89%
# {'bscn_ratio': 0, 'mal': {'total_loss': 58.66478291153908, 'total_correct': tensor(81), 'total': 90, 'evasion': {'total_loss': 58.66478019952774, 'total_correct': tensor(81), 'total': 90}}, 'bon': {'total_loss': 61.58256249316037, 'total_correct': tensor(79), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 4 10
# Time Taken: 59.81253409385681
# Train Epoch (4) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.048308	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 4 10
# Time Taken: 0.026929616928100586
# Train Epoch (4) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.088570	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 4 10
# Time Taken: 0.025931835174560547
# Train Epoch (4) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.002937	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 4 10
# Time Taken: 0.02692723274230957
# Train Epoch (4) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.036204	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 4 10
# Time Taken: 0.028921842575073242
# Train Epoch (4) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.034645	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 4 10
# Time Taken: 0.026927709579467773
# Train Epoch (4) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.222610	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 4 10
# Time Taken: 0.025930404663085938
# Train Epoch (4) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.075493	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 4 10
# Time Taken: 0.023936033248901367
# Train Epoch (4) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.029134	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 4 10
# Time Taken: 0.029919862747192383
# Train Epoch (4) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.105285	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 4 10
# Time Taken: 0.028921842575073242
# Train Epoch (4) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.085133	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 4 10
# Time Taken: 0.026928186416625977
# Train Epoch (4) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.079258	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 4 10
# Time Taken: 0.028922557830810547
# Train Epoch (4) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.034308	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 4 10
# Time Taken: 0.023935794830322266
# Train Epoch (4) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.147366	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 4 10
# Time Taken: 0.042885780334472656
# Train Epoch (4) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.016523	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 4 10
# Time Taken: 0.024933576583862305
# Train Epoch (4) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.156174	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 4 10
# Time Taken: 0.023935317993164062
# Train Epoch (4) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.189328	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 4 10
# Time Taken: 0.02393651008605957
# Train Epoch (4) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.032315	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.6481, Accuracy: 88.89%
# Valid set for malicious : Average Loss: 0.7603, Accuracy: 90.00%
# Valid set for malicious (evasion using natural): Average Loss: 0.7603, Accuracy: 90.00%
# valid set overall: Average Loss: 0.7042, Accuracy: 89.44%
# {'bscn_ratio': 0, 'mal': {'total_loss': 68.42403973639011, 'total_correct': tensor(81), 'total': 90, 'evasion': {'total_loss': 68.42404082417488, 'total_correct': tensor(81), 'total': 90}}, 'bon': {'total_loss': 58.33090204000473, 'total_correct': tensor(80), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 5 10
# Time Taken: 61.38561749458313
# Train Epoch (5) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.050694	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 5 10
# Time Taken: 0.02692699432373047
# Train Epoch (5) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.009923	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 5 10
# Time Taken: 0.026928186416625977
# Train Epoch (5) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.159355	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 5 10
# Time Taken: 0.026929140090942383
# Train Epoch (5) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.011594	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 5 10
# Time Taken: 0.0219423770904541
# Train Epoch (5) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.173758	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 5 10
# Time Taken: 0.018952131271362305
# Train Epoch (5) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.009069	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 5 10
# Time Taken: 0.019948482513427734
# Train Epoch (5) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.027224	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 5 10
# Time Taken: 0.02094244956970215
# Train Epoch (5) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.044387	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 5 10
# Time Taken: 0.022937536239624023
# Train Epoch (5) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.014692	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 5 10
# Time Taken: 0.02094411849975586
# Train Epoch (5) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.194894	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 5 10
# Time Taken: 0.024934053421020508
# Train Epoch (5) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.160320	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 5 10
# Time Taken: 0.021941423416137695
# Train Epoch (5) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.156052	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 5 10
# Time Taken: 0.023936033248901367
# Train Epoch (5) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.231711	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 5 10
# Time Taken: 0.023936033248901367
# Train Epoch (5) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.044147	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 5 10
# Time Taken: 0.025929689407348633
# Train Epoch (5) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.074607	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 5 10
# Time Taken: 0.026928424835205078
# Train Epoch (5) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.060993	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 5 10
# Time Taken: 0.023936748504638672
# Train Epoch (5) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.058692	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.4664, Accuracy: 84.44%
# Valid set for malicious : Average Loss: 0.5652, Accuracy: 94.44%
# Valid set for malicious (evasion using natural): Average Loss: 0.5652, Accuracy: 94.44%
# valid set overall: Average Loss: 0.5158, Accuracy: 89.44%
# {'bscn_ratio': 0, 'mal': {'total_loss': 50.869938388466835, 'total_correct': tensor(85), 'total': 90, 'evasion': {'total_loss': 50.869937896728516, 'total_correct': tensor(85), 'total': 90}}, 'bon': {'total_loss': 41.978877887129784, 'total_correct': tensor(76), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 6 10
# Time Taken: 61.48849391937256
# Train Epoch (6) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.033236	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 6 10
# Time Taken: 0.02892279624938965
# Train Epoch (6) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.081208	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 6 10
# Time Taken: 0.02692723274230957
# Train Epoch (6) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.077670	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 6 10
# Time Taken: 0.0658259391784668
# Train Epoch (6) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.002946	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 6 10
# Time Taken: 0.027925491333007812
# Train Epoch (6) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.031423	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 6 10
# Time Taken: 0.037899017333984375
# Train Epoch (6) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.000008	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 6 10
# Time Taken: 0.021941661834716797
# Train Epoch (6) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.065663	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 6 10
# Time Taken: 0.027926206588745117
# Train Epoch (6) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.012849	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 6 10
# Time Taken: 0.021941184997558594
# Train Epoch (6) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.162566	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 6 10
# Time Taken: 0.02094411849975586
# Train Epoch (6) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.224518	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 6 10
# Time Taken: 0.02194070816040039
# Train Epoch (6) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.034136	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 6 10
# Time Taken: 0.023936748504638672
# Train Epoch (6) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.031161	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 6 10
# Time Taken: 0.02293872833251953
# Train Epoch (6) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.090576	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 6 10
# Time Taken: 0.02493453025817871
# Train Epoch (6) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.038458	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 6 10
# Time Taken: 0.02293848991394043
# Train Epoch (6) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.235913	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 6 10
# Time Taken: 0.019946575164794922
# Train Epoch (6) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.027839	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 6 10
# Time Taken: 0.02094268798828125
# Train Epoch (6) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.021564	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 1.6366, Accuracy: 78.89%
# Valid set for malicious : Average Loss: 0.5561, Accuracy: 93.33%
# Valid set for malicious (evasion using natural): Average Loss: 0.5561, Accuracy: 93.33%
# valid set overall: Average Loss: 1.0963, Accuracy: 86.11%
# {'bscn_ratio': 0, 'mal': {'total_loss': 50.04752270877361, 'total_correct': tensor(84), 'total': 90, 'evasion': {'total_loss': 50.047520875930786, 'total_correct': tensor(84), 'total': 90}}, 'bon': {'total_loss': 147.2930519580841, 'total_correct': tensor(71), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 7 10
# Time Taken: 63.21686601638794
# Train Epoch (7) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.056687	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 7 10
# Time Taken: 0.05385589599609375
# Train Epoch (7) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.058032	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 7 10
# Time Taken: 0.02293872833251953
# Train Epoch (7) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.159160	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 7 10
# Time Taken: 0.02293872833251953
# Train Epoch (7) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.149927	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 7 10
# Time Taken: 0.02094411849975586
# Train Epoch (7) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.128508	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 7 10
# Time Taken: 0.021942138671875
# Train Epoch (7) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.067521	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 7 10
# Time Taken: 0.019948959350585938
# Train Epoch (7) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.069844	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 7 10
# Time Taken: 0.03590202331542969
# Train Epoch (7) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.021752	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 7 10
# Time Taken: 0.022939443588256836
# Train Epoch (7) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.038825	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 7 10
# Time Taken: 0.022938251495361328
# Train Epoch (7) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.106335	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 7 10
# Time Taken: 0.02393794059753418
# Train Epoch (7) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.084393	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 7 10
# Time Taken: 0.03490734100341797
# Train Epoch (7) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.020763	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 7 10
# Time Taken: 0.022938251495361328
# Train Epoch (7) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.110639	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 7 10
# Time Taken: 0.022937536239624023
# Train Epoch (7) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.059934	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 7 10
# Time Taken: 0.021941423416137695
# Train Epoch (7) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.041452	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 7 10
# Time Taken: 0.023934602737426758
# Train Epoch (7) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.071843	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 7 10
# Time Taken: 0.023938655853271484
# Train Epoch (7) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.026839	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 0.9629, Accuracy: 88.89%
# Valid set for malicious : Average Loss: 0.4728, Accuracy: 91.11%
# Valid set for malicious (evasion using natural): Average Loss: 0.4728, Accuracy: 91.11%
# valid set overall: Average Loss: 0.7179, Accuracy: 90.00%
# {'bscn_ratio': 0, 'mal': {'total_loss': 42.555739521980286, 'total_correct': tensor(82), 'total': 90, 'evasion': {'total_loss': 42.55573892593384, 'total_correct': tensor(82), 'total': 90}}, 'bon': {'total_loss': 86.66127276420593, 'total_correct': tensor(80), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 8 10
# Time Taken: 60.117398738861084
# Train Epoch (8) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.015318	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 8 10
# Time Taken: 0.026929140090942383
# Train Epoch (8) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.006471	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 8 10
# Time Taken: 0.028922080993652344
# Train Epoch (8) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.144724	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 8 10
# Time Taken: 0.02094292640686035
# Train Epoch (8) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.006015	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 8 10
# Time Taken: 0.021940231323242188
# Train Epoch (8) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.047766	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 8 10
# Time Taken: 0.024934053421020508
# Train Epoch (8) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.003297	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 8 10
# Time Taken: 0.021941423416137695
# Train Epoch (8) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.006752	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 8 10
# Time Taken: 0.029920578002929688
# Train Epoch (8) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.018296	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 8 10
# Time Taken: 0.022939205169677734
# Train Epoch (8) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.090650	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 8 10
# Time Taken: 0.020943641662597656
# Train Epoch (8) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.002340	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 8 10
# Time Taken: 0.023935794830322266
# Train Epoch (8) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.080243	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 8 10
# Time Taken: 0.024935483932495117
# Train Epoch (8) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.046991	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 8 10
# Time Taken: 0.020943880081176758
# Train Epoch (8) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.052497	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 8 10
# Time Taken: 0.02393627166748047
# Train Epoch (8) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.004157	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 8 10
# Time Taken: 0.020943641662597656
# Train Epoch (8) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.040637	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 8 10
# Time Taken: 0.0219419002532959
# Train Epoch (8) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.227848	Batch Accuracy: 93.8%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 8 10
# Time Taken: 0.02094411849975586
# Train Epoch (8) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.036919	Batch Accuracy: 96.4%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 1.2049, Accuracy: 91.11%
# Valid set for malicious : Average Loss: 1.6102, Accuracy: 81.11%
# Valid set for malicious (evasion using natural): Average Loss: 1.6102, Accuracy: 81.11%
# valid set overall: Average Loss: 1.4076, Accuracy: 86.11%
# {'bscn_ratio': 0, 'mal': {'total_loss': 144.9199696779251, 'total_correct': tensor(73), 'total': 90, 'evasion': {'total_loss': 144.91997489333153, 'total_correct': tensor(73), 'total': 90}}, 'bon': {'total_loss': 108.44136261885433, 'total_correct': tensor(82), 'total_evade': None, 'total': 90}}
# dataloaderr <datasets.datasets.PortableExecutableDataset object at 0x000002ACEDC0B4A8> <datasets.datasets.PortableExecutableDataset object at 0x000002ACEAD00048>
# This is bacth_idx 0
# BETA VALS
# 0 540 Standard 9 10
# Time Taken: 60.229018449783325
# Train Epoch (9) | Batch (0) | [0/540 (0%)]	Batch Loss: 0.009330	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 1
# BETA VALS
# 1 540 Standard 9 10
# Time Taken: 0.02393651008605957
# Train Epoch (9) | Batch (1) | [32/540 (6%)]	Batch Loss: 0.045000	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 2
# BETA VALS
# 2 540 Standard 9 10
# Time Taken: 0.025929927825927734
# Train Epoch (9) | Batch (2) | [64/540 (12%)]	Batch Loss: 0.047555	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 3
# BETA VALS
# 3 540 Standard 9 10
# Time Taken: 0.02393794059753418
# Train Epoch (9) | Batch (3) | [96/540 (18%)]	Batch Loss: 0.043722	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 4
# BETA VALS
# 4 540 Standard 9 10
# Time Taken: 0.02094268798828125
# Train Epoch (9) | Batch (4) | [128/540 (24%)]	Batch Loss: 0.062917	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 5
# BETA VALS
# 5 540 Standard 9 10
# Time Taken: 0.018948793411254883
# Train Epoch (9) | Batch (5) | [160/540 (29%)]	Batch Loss: 0.120961	Batch Accuracy: 90.6%	 BSCN: 1.000000000000
# This is bacth_idx 6
# BETA VALS
# 6 540 Standard 9 10
# Time Taken: 0.01894998550415039
# Train Epoch (9) | Batch (6) | [192/540 (35%)]	Batch Loss: 0.014409	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 7
# BETA VALS
# 7 540 Standard 9 10
# Time Taken: 0.021941184997558594
# Train Epoch (9) | Batch (7) | [224/540 (41%)]	Batch Loss: 0.019256	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 8
# BETA VALS
# 8 540 Standard 9 10
# Time Taken: 0.02692699432373047
# Train Epoch (9) | Batch (8) | [256/540 (47%)]	Batch Loss: 0.054113	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 9
# BETA VALS
# 9 540 Standard 9 10
# Time Taken: 0.022939443588256836
# Train Epoch (9) | Batch (9) | [288/540 (53%)]	Batch Loss: 0.043621	Batch Accuracy: 96.9%	 BSCN: 1.000000000000
# This is bacth_idx 10
# BETA VALS
# 10 540 Standard 9 10
# Time Taken: 0.025931596755981445
# Train Epoch (9) | Batch (10) | [320/540 (59%)]	Batch Loss: 0.056883	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 11
# BETA VALS
# 11 540 Standard 9 10
# Time Taken: 0.024934053421020508
# Train Epoch (9) | Batch (11) | [352/540 (65%)]	Batch Loss: 0.015830	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 12
# BETA VALS
# 12 540 Standard 9 10
# Time Taken: 0.019946575164794922
# Train Epoch (9) | Batch (12) | [384/540 (71%)]	Batch Loss: 0.026999	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 13
# BETA VALS
# 13 540 Standard 9 10
# Time Taken: 0.02293848991394043
# Train Epoch (9) | Batch (13) | [416/540 (76%)]	Batch Loss: 0.002530	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 14
# BETA VALS
# 14 540 Standard 9 10
# Time Taken: 0.020943880081176758
# Train Epoch (9) | Batch (14) | [448/540 (82%)]	Batch Loss: 0.000367	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 15
# BETA VALS
# 15 540 Standard 9 10
# Time Taken: 0.020944595336914062
# Train Epoch (9) | Batch (15) | [480/540 (88%)]	Batch Loss: 0.000179	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# This is bacth_idx 16
# BETA VALS
# 16 540 Standard 9 10
# Time Taken: 0.020943403244018555
# Train Epoch (9) | Batch (16) | [448/540 (94%)]	Batch Loss: 0.000556	Batch Accuracy: 100.0%	 BSCN: 1.000000000000
# Valid set for benign : Average Loss: 2.5098, Accuracy: 85.56%
# Valid set for malicious : Average Loss: 1.2501, Accuracy: 92.22%
# Valid set for malicious (evasion using natural): Average Loss: 1.2501, Accuracy: 92.22%
# valid set overall: Average Loss: 1.8800, Accuracy: 88.89%
# {'bscn_ratio': 0, 'mal': {'total_loss': 112.50659851357341, 'total_correct': tensor(83), 'total': 90, 'evasion': {'total_loss': 112.50660043163225, 'total_correct': tensor(83), 'total': 90}}, 'bon': {'total_loss': 225.8847360610962, 'total_correct': tensor(77), 'total_evade': None, 'total': 90}}
# METRICS TO DUMP
# {'bscn_ratio': 0, 'mal': {'total_loss': 36.540499806404114, 'total_correct': tensor(80), 'total': 90, 'evasion': {'total_loss': 36.540499806404114, 'total_correct': tensor(80), 'total': 90}}, 'bon': {'total_loss': 19.373232007026672, 'total_correct': tensor(84), 'total_evade': None, 'total': 90}}

# %%
type(_metrics)
# Out:
# dict

# %%
_metrics
# Out:
# {'bscn_ratio': 0,
#  'mal': {'total_loss': 36.540499806404114,
#   'total_correct': tensor(80),
#   'total': 90,
#   'evasion': {'total_loss': 36.540499806404114,
#    'total_correct': tensor(80),
#    'total': 90}},
#  'bon': {'total_loss': 19.373232007026672,
#   'total_correct': tensor(84),
#   'total_evade': None,
#   'total': 90}}

# %%
_metrics['mal']['total']
# Out:
# 90

# %%
def confMat(_metrics):
    total_mal = _metrics['mal']['total']
    total_mal_correct = _metrics['mal']['total_correct']
    total_mal_wrong = total_mal - total_mal_correct
    
    total_ben = _metrics['bon']['total']
    total_ben_correct = _metrics['bon']['total_correct']
    total_ben_wrong = total_ben - total_ben_correct
    
    true_list = []
    for i in range(total_mal):
        true_list.append(1)
    for i in range(total_ben):
        true_list.append(0)
        
    pred_list = []
    for i in range(total_mal_correct):
        pred_list.append(1)
    for i in range(total_mal_wrong):
        pred_list.append(0)
    for i in range(total_ben_correct):
        pred_list.append(0)
    for i in range(total_ben_wrong):
        pred_list.append(1)
    return true_list,pred_list

# %%
TrueList,PredList = confMat(_metrics)

# %%
np.unique(np.array(TrueList),return_counts=True)
# Out:
# (array([0, 1]), array([90, 90], dtype=int64))

# %%
np.unique(np.array(PredList),return_counts=True)
# Out:
# (array([0, 1]), array([94, 86], dtype=int64))

# %%
from sklearn import metrics

# %%
print(metrics.confusion_matrix(TrueList,PredList))
# Out:
# [[84  6]
#  [10 80]]

# %%
print(metrics.classification_report(TrueList,PredList))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        90
#            1       0.93      0.89      0.91        90
#
#     accuracy                           0.91       180
#    macro avg       0.91      0.91      0.91       180
# weighted avg       0.91      0.91      0.91       180
